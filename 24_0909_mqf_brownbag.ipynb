# %% [markdown]
# ### START

# %%
pip install wrds
# Out:
# Requirement already satisfied: wrds in c:\users\lhtee\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\lhtee\anaconda3\lib\site-packages (from wrds) (1.21.5)
# Requirement already satisfied: pandas in c:\users\lhtee\anaconda3\lib\site-packages (from wrds) (1.4.2)
# Requirement already satisfied: sqlalchemy in c:\users\lhtee\anaconda3\lib\site-packages (from wrds) (1.4.32)
# Requirement already satisfied: psycopg2-binary in c:\users\lhtee\anaconda3\lib\site-packages (from wrds) (2.9.5)
# Requirement already satisfied: mock in c:\users\lhtee\anaconda3\lib\site-packages (from wrds) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lhtee\anaconda3\lib\site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lhtee\anaconda3\lib\site-packages (from pandas->wrds) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\lhtee\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lhtee\anaconda3\lib\site-packages (from sqlalchemy->wrds) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import wrds
db = wrds.Connection()
# Out:
# Enter your WRDS username [lhtee]:ltee11
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Created .pgpass file successfully.
# Loading library list...
# Done

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
lib
#sorted(lib)
# Out:
# ['aha_sample',
#  'audit',
#  'audit_acct_os',
#  'audit_common',
#  'audit_corp_legal',
#  'audit_europe',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'block',
#  'block_all',
#  'boardex_trial',
#  'boardsmp',
#  'bvd',
#  'bvd_amadeus_trial',
#  'bvd_orbis_large',
#  'bvd_orbis_medium',
#  'bvd_orbis_small',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'ciq',
#  'ciq_common',
#  'ciq_pplintel',
#  'ciq_ratings',
#  'ciqsamp',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_transcripts',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'comp_ratings',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'compa',
#  'compb',
#  'compg',
#  'compm',
#  'compsamp_snapshot',
#  'compseg',
#  'comscore',
#  'comscore_2018',
#  'comscore_2019',
#  'comscore_2020',
#  'comscore_common',
#  'contrib',
#  'contrib_as_filed_financials',
#  'contrib_ceo_turnover',
#  'contrib_char_returns',
#  'contrib_general',
#  'contrib_global_factor',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_q_indexes',
#  'crsp_q_indexhist',
#  'crsp_q_mutualfunds',
#  'crspq',
#  'csmar',
#  'csmar_financial',
#  'csmar_funds',
#  'csmar_trade',
#  'dealscan',
#  'djones',
#  'djones_all',
#  'dmef',
#  'dmef_all',
#  'doe',
#  'doe_all',
#  'etfg',
#  'etfg_analytics',
#  'etfg_constituents',
#  'etfg_fund_flow',
#  'etfg_industry',
#  'etfg_samp',
#  'etfgsamp',
#  'eurekahedge_sample',
#  'eursamp',
#  'execcomp',
#  'factsamp_all',
#  'factsamp_revere',
#  'ff',
#  'ff_all',
#  'fisdsamp',
#  'fisdsamp_all',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'frb_all',
#  'fssamp',
#  'ftse',
#  'ftse_russell_us',
#  'gmi',
#  'gmi_all',
#  'govpxsamp_all',
#  'govpxsmp',
#  'gutenberg',
#  'hbase_sample',
#  'hbsamp',
#  'hfrsamp',
#  'hfrsamp_hfrdb',
#  'ibes',
#  'ifgrsamp',
#  'ims_obp_trial',
#  'imssamp',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'iss_va_shareholder',
#  'issm_nasd1987',
#  'issm_nasd1988',
#  'issm_nasd1989',
#  'issm_nasd1990',
#  'issm_nasd1991',
#  'issm_nasd1992',
#  'issm_nyam1983',
#  'issm_nyam1984',
#  'issm_nyam1985',
#  'issm_nyam1986',
#  'issm_nyam1987',
#  'issm_nyam1988',
#  'issm_nyam1989',
#  'issm_nyam1990',
#  'issm_nyam1991',
#  'issm_nyam1992',
#  'ktmine_patents_samp',
#  'ktsamp',
#  'lvnsamp',
#  'lvnsamp_all',
#  'macrofin',
#  'macrofin_comm_trade',
#  'mfl',
#  'mflinks_all',
#  'midas',
#  'mrktsamp',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'mrktsamp_msf',
#  'msrb',
#  'msrb_all',
#  'omtrial',
#  'optionm',
#  'optionm_all',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'otc',
#  'otc_endofday',
#  'permstub_all',
#  'phlx',
#  'phlx_all',
#  'pitchsmp',
#  'ppubsamp',
#  'ppubsamp_d4d',
#  'preqin',
#  'preqin_pe',
#  'preqin_vc',
#  'preqsamp',
#  'preqsamp_all',
#  'public_all',
#  'pwt',
#  'pwt_all',
#  'ravenpack_common',
#  'ravenpack_dj',
#  'ravenpack_trial',
#  'reprisk',
#  'reprisk_sample',
#  'reprisk_v2',
#  'repsamp',
#  'revelio_samp',
#  'revsamp',
#  'risk',
#  'risk_directors',
#  'risk_governance',
#  'risk_proposals',
#  'risk_votes',
#  'risksamp',
#  'risksamp_all',
#  'rpna',
#  'rpnasamp',
#  'rq_all',
#  'rstat_samp',
#  'rstatsmp',
#  'secsamp',
#  'secsamp_all',
#  'snapsamp',
#  'snlsamp',
#  'snlsamp_fig',
#  'sprat',
#  'sustain',
#  'sustainalytics_all',
#  'sustainalyticssamp_all',
#  'sustsamp',
#  'taqm_2003',
#  'taqm_2004',
#  'taqm_2005',
#  'taqm_2006',
#  'taqm_2007',
#  'taqm_2008',
#  'taqm_2009',
#  'taqm_2010',
#  'taqm_2011',
#  'taqm_2012',
#  'taqm_2013',
#  'taqm_2014',
#  'taqm_2015',
#  'taqm_2016',
#  'taqm_2017',
#  'taqm_2018',
#  'taqm_2019',
#  'taqm_2020',
#  'taqm_2021',
#  'taqmsamp',
#  'taqmsamp_all',
#  'taqmsec',
#  'taqsamp',
#  'tfn',
#  'totalq',
#  'totalq_all',
#  'tr_13f',
#  'tr_common',
#  'tr_dealscan',
#  'tr_ds_comds',
#  'tr_ds_econ',
#  'tr_ds_equities',
#  'tr_ds_fut',
#  'tr_ibes',
#  'tr_ibes_guidance',
#  'tr_ibes_iga',
#  'tr_insiders',
#  'tr_mutualfunds',
#  'tr_ownership',
#  'tr_worldscope',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trdssamp',
#  'trdstrm',
#  'trown',
#  'trsamp',
#  'trsamp_ds_eq',
#  'trsamp_dscom',
#  'trsamp_dsecon',
#  'trsamp_dsfut',
#  'trsamp_worldscope',
#  'trws',
#  'twoiq_samp',
#  'twoiqsmp',
#  'wappsamp',
#  'windsmp',
#  'wrds_lib_internal',
#  'wrds_sec_search',
#  'wrdsapps',
#  'wrdsapps_backtest_basic',
#  'wrdsapps_backtest_plus',
#  'wrdsapps_eushort',
#  'wrdsapps_evtstudy_int_ginsight',
#  'wrdsapps_evtstudy_lr',
#  'wrdsapps_finratio',
#  'wrdsapps_finratio_ccm',
#  'wrdsapps_finratio_ibes',
#  'wrdsapps_finratio_ibes_ccm',
#  'wrdsapps_link_comp_eushort',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm',
#  'wrdsapps_link_datastream_wscope',
#  'wrdsapps_link_supplychain',
#  'wrdsapps_patents',
#  'wrdsapps_plink_exec_ciq',
#  'wrdsapps_plink_exec_trinsider',
#  'wrdsapps_plink_trinsider_ciq',
#  'wrdsapps_subsidiary',
#  'wrdsapps_windices',
#  'wrdsappssamp_all',
#  'wrdssec',
#  'wrdssec_all',
#  'wrdssec_bow',
#  'wrdssec_common',
#  'wrdssec_insiders',
#  'wrdssec_midas',
#  'wrdssec_secsa',
#  'zacksamp',
#  'zacksamp_all']

# %% [markdown]
# ### CRSP

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
crsp = [x for x in lib if 'crsp' in x]
crsp



#crsp = list(filter(lambda x: 'crsp' in x, lib))
#crsp

#import re
#crsp = [x for x in lib if re.search('crsp', x)]
#crsp
# Out:
# ['crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_q_indexes',
#  'crsp_q_indexhist',
#  'crsp_q_mutualfunds',
#  'crspq',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm']

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp')
tables
# Out:
# ['acti',
#  'asia',
#  'asib',
#  'asic',
#  'asio',
#  'asix',
#  'bmdebt',
#  'bmheader',
#  'bmpaymts',
#  'bmquotes',
#  'bmyield',
#  'bndprt06',
#  'bndprt12',
#  'bxcalind',
#  'bxdlyind',
#  'bxmthind',
#  'bxquotes',
#  'bxyield',
#  'cap',
#  'ccm_lookup',
#  'ccm_qvards',
#  'ccmxpf_linktable',
#  'ccmxpf_lnkhist',
#  'ccmxpf_lnkrng',
#  'ccmxpf_lnkused',
#  'comphead',
#  'comphist',
#  'compmaster',
#  'contact_info',
#  'crsp_cik_map',
#  'crsp_daily_data',
#  'crsp_header',
#  'crsp_monthly_data',
#  'crsp_names',
#  'crsp_portno_map',
#  'crsp_ziman_daily_index',
#  'crsp_ziman_monthly_index',
#  'cs20yr',
#  'cs5yr',
#  'cs90d',
#  'cst_hist',
#  'daily_nav',
#  'daily_nav_ret',
#  'daily_returns',
#  'dividends',
#  'dport1',
#  'dport2',
#  'dport3',
#  'dport4',
#  'dport5',
#  'dport6',
#  'dport7',
#  'dport8',
#  'dport9',
#  'dsbc',
#  'dsbo',
#  'dse',
#  'dse62',
#  'dse62delist',
#  'dse62dist',
#  'dse62exchdates',
#  'dse62names',
#  'dse62nasdin',
#  'dse62shares',
#  'dseall',
#  'dseall62',
#  'dsedelist',
#  'dsedist',
#  'dseexchdates',
#  'dsenames',
#  'dsenasdin',
#  'dseshares',
#  'dsf',
#  'dsf62',
#  'dsf62_v2',
#  'dsf_v2',
#  'dsfhdr',
#  'dsfhdr62',
#  'dsi',
#  'dsi62',
#  'dsia',
#  'dsib',
#  'dsic',
#  'dsio',
#  'dsir',
#  'dsix',
#  'dsiy',
#  'dsp500',
#  'dsp500_v2',
#  'dsp500list',
#  'dsp500list_v2',
#  'dsp500p',
#  'dssc',
#  'dsso',
#  'eod_cap',
#  'eod_sector',
#  'eod_vg',
#  'erdport1',
#  'erdport2',
#  'erdport3',
#  'erdport4',
#  'erdport5',
#  'erdport6',
#  'erdport7',
#  'erdport8',
#  'erdport9',
#  'ermport1',
#  'ermport2',
#  'ermport3',
#  'ermport4',
#  'ermport5',
#  'fbpri',
#  'fbyld',
#  'front_load',
#  'front_load_det',
#  'front_load_grp',
#  'fund_fees',
#  'fund_flows',
#  'fund_hdr',
#  'fund_hdr_hist',
#  'fund_names',
#  'fund_style',
#  'fund_summary',
#  'fund_summary2',
#  'fwdask06',
#  'fwdask12',
#  'fwdave06',
#  'fwdave12',
#  'fwdbid06',
#  'fwdbid12',
#  'hldask06',
#  'hldask12',
#  'hldave06',
#  'hldave12',
#  'hldbid06',
#  'hldbid12',
#  'holdings',
#  'holdings_co_info',
#  'inddlyseriesdata',
#  'inddlyseriesdata62',
#  'inddlyseriesdata_ind',
#  'index_descriptions',
#  'index_type_map',
#  'indfamilyinfohdr',
#  'indfamilyinfohdr62',
#  'indfamilyinfohdr_ind',
#  'indissrebalancesummary_ind',
#  'indmthseriesdata',
#  'indmthseriesdata62',
#  'indmthseriesdata_ind',
#  'indsecrebalancesummary_ind',
#  'indseriesinfohdr',
#  'indseriesinfohdr62',
#  'indseriesinfohdr_ind',
#  'mbi',
#  'mbmdat',
#  'mbmhdr',
#  'mbx',
#  'mbxid',
#  'mcti',
#  'metacalendarperiod',
#  'metacalendarperiod62',
#  'metacalendarperiod_ind',
#  'metacolumncoverage',
#  'metacolumncoverage62',
#  'metacolumncoverage_ind',
#  'metacolumninfo',
#  'metacolumninfo62',
#  'metacolumninfo_ind',
#  'metaexchangecalendar',
#  'metaexchangecalendar62',
#  'metaexchangecalendar_ind',
#  'metafileinfo',
#  'metafileinfo62',
#  'metafileinfo_ind',
#  'metaflagcoverage',
#  'metaflagcoverage62',
#  'metaflagcoverage_ind',
#  'metaflaginfo',
#  'metaflaginfo62',
#  'metaflaginfo_ind',
#  'metaflagtype',
#  'metaflagtype62',
#  'metaflagtype_ind',
#  'metaiteminfo',
#  'metaiteminfo62',
#  'metaiteminfo_ind',
#  'metasiztociz',
#  'metasiztociz62',
#  'metasiztociz_ind',
#  'mfdbname',
#  'mhista',
#  'mhistn',
#  'mhistq',
#  'monthly_nav',
#  'monthly_returns',
#  'monthly_tna',
#  'monthly_tna_ret_nav',
#  'mport1',
#  'mport2',
#  'mport3',
#  'mport4',
#  'mport5',
#  'mse',
#  'mse62',
#  'mse62delist',
#  'mse62dist',
#  'mse62exchdates',
#  'mse62names',
#  'mse62nasdin',
#  'mse62shares',
#  'mseall',
#  'mseall62',
#  'msedelist',
#  'msedist',
#  'mseexchdates',
#  'msenames',
#  'msenasdin',
#  'mseshares',
#  'msf',
#  'msf62',
#  'msf62_v2',
#  'msf_v2',
#  'msfhdr',
#  'msfhdr62',
#  'msi',
#  'msi62',
#  'msia',
#  'msib',
#  'msic',
#  'msio',
#  'msir',
#  'msix',
#  'msiy',
#  'msp500',
#  'msp500_v2',
#  'msp500list',
#  'msp500list_v2',
#  'msp500p',
#  'portnomap',
#  'priask06',
#  'priask12',
#  'priave06',
#  'priave12',
#  'pribid06',
#  'pribid12',
#  'price_type',
#  'property_type',
#  'qcti',
#  'qsia',
#  'qsib',
#  'qsic',
#  'qsio',
#  'qsix',
#  'rear_load',
#  'rear_load_det',
#  'rear_load_grp',
#  'rebala',
#  'rebaln',
#  'rebalq',
#  'reit_type',
#  'riskfree',
#  's6z_agg_ann',
#  's6z_agg_mth',
#  's6z_agg_qtr',
#  's6z_del',
#  's6z_dind',
#  's6z_dis',
#  's6z_dp_dly',
#  's6z_ds_dly',
#  's6z_hdr',
#  's6z_indhdr',
#  's6z_mdel',
#  's6z_mind',
#  's6z_mth',
#  's6z_nam',
#  's6z_ndi',
#  's6z_shr',
#  'saz_agg_ann',
#  'saz_agg_mth',
#  'saz_agg_qtr',
#  'saz_del',
#  'saz_dind',
#  'saz_dis',
#  'saz_dp_dly',
#  'saz_ds_dly',
#  'saz_hdr',
#  'saz_indhdr',
#  'saz_mdel',
#  'saz_mind',
#  'saz_mth',
#  'saz_nam',
#  'saz_ndi',
#  'saz_shr',
#  'sechead',
#  'sechist',
#  'sector',
#  'sfz_dind',
#  'sfz_indhdr',
#  'sfz_mbr',
#  'sfz_mind',
#  'sfz_portd',
#  'sfz_portm',
#  'sfz_rb',
#  'stkannsecuritydata',
#  'stkannsecuritydata62',
#  'stkdelists',
#  'stkdelists62',
#  'stkdistributions',
#  'stkdistributions62',
#  'stkdlysecuritydata',
#  'stkdlysecuritydata62',
#  'stkdlysecurityprimarydata',
#  'stkdlysecurityprimarydata62',
#  'stkindissuerstatistics_ind',
#  'stkindmembership_ind',
#  'stkindsecuritystatistics_ind',
#  'stkissuerinfohdr',
#  'stkissuerinfohdr62',
#  'stkissuerinfohist',
#  'stkissuerinfohist62',
#  'stkmthfloatshares',
#  'stkmthfloatshares62',
#  'stkmthsecuritydata',
#  'stkmthsecuritydata62',
#  'stkqtrsecuritydata',
#  'stkqtrsecuritydata62',
#  'stksecurityinfohdr',
#  'stksecurityinfohdr62',
#  'stksecurityinfohist',
#  'stksecurityinfohist62',
#  'stkshares',
#  'stkshares62',
#  'stock_qvards',
#  'stocknames',
#  'stocknames62',
#  'stocknames62_v2',
#  'stocknames_v2',
#  'sub_property_type',
#  'tfz_dly',
#  'tfz_dly_cd',
#  'tfz_dly_cpi',
#  'tfz_dly_ft',
#  'tfz_dly_rf2',
#  'tfz_dly_ts2',
#  'tfz_idx',
#  'tfz_iss',
#  'tfz_mast',
#  'tfz_mth',
#  'tfz_mth_bp',
#  'tfz_mth_cd',
#  'tfz_mth_cpi',
#  'tfz_mth_fb',
#  'tfz_mth_ft',
#  'tfz_mth_rf',
#  'tfz_mth_rf2',
#  'tfz_mth_ts',
#  'tfz_mth_ts2',
#  'tfz_pay',
#  'vg',
#  'wrds_dailyindexret62_query',
#  'wrds_dailyindexret_query',
#  'wrds_dsf62v2_query',
#  'wrds_dsfv2_query',
#  'wrds_inddlytranspose_query',
#  'wrds_indmthtranspose_query',
#  'wrds_monthlyindexret62_query',
#  'wrds_monthlyindexret_query',
#  'wrds_msf62v2_query',
#  'wrds_msfv2_query',
#  'wrds_names62_query',
#  'wrds_names_query',
#  'yldask06',
#  'yldask12',
#  'yldave06',
#  'yldave12',
#  'yldbid06',
#  'yldbid12',
#  'ziman_reit_info',
#  'zr_hdrnames']

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp_a_stock')
tables
# Out:
# ['dse',
#  'dseall',
#  'dsedelist',
#  'dsedist',
#  'dseexchdates',
#  'dsenames',
#  'dsenasdin',
#  'dseshares',
#  'dsf',
#  'dsf_v2',
#  'dsfhdr',
#  'dsi',
#  'dsiy',
#  'inddlyseriesdata',
#  'indfamilyinfohdr',
#  'indmthseriesdata',
#  'indseriesinfohdr',
#  'metacalendarperiod',
#  'metacolumncoverage',
#  'metacolumninfo',
#  'metaexchangecalendar',
#  'metafileinfo',
#  'metaflagcoverage',
#  'metaflaginfo',
#  'metaflagtype',
#  'metaiteminfo',
#  'metasiztociz',
#  'mse',
#  'mseall',
#  'msedelist',
#  'msedist',
#  'mseexchdates',
#  'msenames',
#  'msenasdin',
#  'mseshares',
#  'msf',
#  'msf_v2',
#  'msfhdr',
#  'msi',
#  'msiy',
#  'saz_agg_ann',
#  'saz_agg_mth',
#  'saz_agg_qtr',
#  'saz_del',
#  'saz_dind',
#  'saz_dis',
#  'saz_dp_dly',
#  'saz_ds_dly',
#  'saz_hdr',
#  'saz_indhdr',
#  'saz_mdel',
#  'saz_mind',
#  'saz_mth',
#  'saz_nam',
#  'saz_ndi',
#  'saz_shr',
#  'stkannsecuritydata',
#  'stkdelists',
#  'stkdistributions',
#  'stkdlysecuritydata',
#  'stkdlysecurityprimarydata',
#  'stkissuerinfohdr',
#  'stkissuerinfohist',
#  'stkmthfloatshares',
#  'stkmthsecuritydata',
#  'stkqtrsecuritydata',
#  'stksecurityinfohdr',
#  'stksecurityinfohist',
#  'stkshares',
#  'stock_qvards',
#  'stocknames',
#  'stocknames_v2',
#  'wrds_dailyindexret_query',
#  'wrds_dsfv2_query',
#  'wrds_monthlyindexret_query',
#  'wrds_msfv2_query',
#  'wrds_names_query']

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp_a_stock')

#open file in write mode
with open(r'tables_OF_crsp_a_stock_24_0909.txt', 'w') as a:

    for b in tables:
        #write each item on a new line
        a.write("%s\n" % b)
    print()

# %%
#import wrds
#db = wrds.Connection()
column_headers = db.describe_table(library='crsp', table='msf')
column_headers

#import wrds
#db = wrds.Connection()
#db.describe_table(library='crsp', table='msf')
# Out:
# Approximately 4922867 rows in crsp.msf.
#         name  nullable              type comment
# 0      cusip      True        VARCHAR(8)    None
# 1     permno      True  DOUBLE_PRECISION    None
# 2     permco      True  DOUBLE_PRECISION    None
# 3     issuno      True  DOUBLE_PRECISION    None
# 4      hexcd      True  DOUBLE_PRECISION    None
# 5     hsiccd      True  DOUBLE_PRECISION    None
# 6       date      True              DATE    None
# 7      bidlo      True  DOUBLE_PRECISION    None
# 8      askhi      True  DOUBLE_PRECISION    None
# 9        prc      True  DOUBLE_PRECISION    None
# 10       vol      True  DOUBLE_PRECISION    None
# 11       ret      True  DOUBLE_PRECISION    None
# 12       bid      True  DOUBLE_PRECISION    None
# 13       ask      True  DOUBLE_PRECISION    None
# 14    shrout      True  DOUBLE_PRECISION    None
# 15    cfacpr      True  DOUBLE_PRECISION    None
# 16   cfacshr      True  DOUBLE_PRECISION    None
# 17    altprc      True  DOUBLE_PRECISION    None
# 18    spread      True  DOUBLE_PRECISION    None
# 19  altprcdt      True              DATE    None
# 20      retx      True  DOUBLE_PRECISION    None

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='crsp_a_stock', table='msf')
# Out:
# Approximately 4922867 rows in crsp_a_stock.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True  DOUBLE_PRECISION
# 2     permco      True  DOUBLE_PRECISION
# 3     issuno      True  DOUBLE_PRECISION
# 4      hexcd      True  DOUBLE_PRECISION
# 5     hsiccd      True  DOUBLE_PRECISION
# 6       date      True              DATE
# 7      bidlo      True  DOUBLE_PRECISION
# 8      askhi      True  DOUBLE_PRECISION
# 9        prc      True  DOUBLE_PRECISION
# 10       vol      True  DOUBLE_PRECISION
# 11       ret      True  DOUBLE_PRECISION
# 12       bid      True  DOUBLE_PRECISION
# 13       ask      True  DOUBLE_PRECISION
# 14    shrout      True  DOUBLE_PRECISION
# 15    cfacpr      True  DOUBLE_PRECISION
# 16   cfacshr      True  DOUBLE_PRECISION
# 17    altprc      True  DOUBLE_PRECISION
# 18    spread      True  DOUBLE_PRECISION
# 19  altprcdt      True              DATE
# 20      retx      True  DOUBLE_PRECISION
#
#                                     comment
# 0                              CUSIP Header
# 1                                    PERMNO
# 2                                    PERMCO
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18               Spread Between Bid and Ask
# 19                     Alternate Price Date
# 20                Returns without Dividends

# %%
column_headers = db.describe_table(library='crsp_a_stock', table='msf')
print(column_headers.to_string())
# Out:
# Approximately 4922867 rows in crsp_a_stock.msf.
#         name  nullable              type                                  comment
# 0      cusip      True        VARCHAR(8)                             CUSIP Header
# 1     permno      True  DOUBLE_PRECISION                                   PERMNO
# 2     permco      True  DOUBLE_PRECISION                                   PERMCO
# 3     issuno      True  DOUBLE_PRECISION                      Nasdaq Issue Number
# 4      hexcd      True  DOUBLE_PRECISION                     Exchange Code Header
# 5     hsiccd      True  DOUBLE_PRECISION  Standard Industrial Classification Code
# 6       date      True              DATE                      Date of Observation
# 7      bidlo      True  DOUBLE_PRECISION                         Bid or Low Price
# 8      askhi      True  DOUBLE_PRECISION                        Ask or High Price
# 9        prc      True  DOUBLE_PRECISION                 Price or Bid/Ask Average
# 10       vol      True  DOUBLE_PRECISION                                   Volume
# 11       ret      True  DOUBLE_PRECISION                                  Returns
# 12       bid      True  DOUBLE_PRECISION                                      Bid
# 13       ask      True  DOUBLE_PRECISION                                      Ask
# 14    shrout      True  DOUBLE_PRECISION                       Shares Outstanding
# 15    cfacpr      True  DOUBLE_PRECISION       Cumulative Factor to Adjust Prices
# 16   cfacshr      True  DOUBLE_PRECISION   Cumulative Factor to Adjust Shares/Vol
# 17    altprc      True  DOUBLE_PRECISION                          Price Alternate
# 18    spread      True  DOUBLE_PRECISION               Spread Between Bid and Ask
# 19  altprcdt      True              DATE                     Alternate Price Date
# 20      retx      True  DOUBLE_PRECISION                Returns without Dividends

# %%
#import wrds
#db = wrds.Connection()
db.get_row_count(library='crsp_a_stock', table='msf')
#db.get_row_count('crsp_a_stock', 'msf')
# Out:
# 4922867

# %%
#pip install wrds

#import wrds
#db = wrds.Connection()

#db.list_libraries()

#db.list_tables(library='crsp_a_stock')
#db.list_tables('crsp_a_stock')

#db.describe_table(library='crsp_a_stock', table='msf')
#db.describe_table('crsp_a_stock','msf')

#db.get_row_count(library='crsp_a_stock', table='msf')
#db.get_row_count('crsp_a_stock', 'msf')

# %%
#import wrds
#import pandas
#db = wrds.Connection()

#db.get_table(library='crsp_a_stock', table='msf')
db.get_table(library='crsp_a_stock', table='msf', obs=10)
# Out:
#       cusip   permno  permco   issuno  hexcd  hsiccd        date    bidlo  \
# 0  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1985-12-31      NaN
# 1  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-01-31 -2.50000
# 2  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-02-28 -3.25000
# 3  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-03-31 -3.25000
# 4  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-04-30 -4.00000
# 5  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-05-30 -3.06250
# 6  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-06-30 -2.90625
# 7  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-07-31 -2.59375
# 8  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-08-29 -1.03125
# 9  68391610  10000.0  7952.0  10396.0    3.0  3990.0  1986-09-30 -0.96875
#
#       askhi       prc  ...       ret   bid   ask  shrout  cfacpr  cfacshr  \
# 0       NaN       NaN  ...       NaN  None  None     NaN     NaN      NaN
# 1 -4.437500 -4.375000  ...       NaN  None  None  3680.0     1.0      1.0
# 2 -4.375000 -3.250000  ... -0.257143  None  None  3680.0     1.0      1.0
# 3 -4.437500 -4.437500  ...  0.365385  None  None  3680.0     1.0      1.0
# 4 -4.312500 -4.000000  ... -0.098592  None  None  3793.0     1.0      1.0
# 5 -4.218750 -3.109375  ... -0.222656  None  None  3793.0     1.0      1.0
# 6 -3.296875 -3.093750  ... -0.005025  None  None  3793.0     1.0      1.0
# 7 -3.437500 -2.843750  ... -0.080808  None  None  3793.0     1.0      1.0
# 8 -2.625000 -1.093750  ... -0.615385  None  None  3793.0     1.0      1.0
# 9 -1.281250 -1.031250  ... -0.057143  None  None  3793.0     1.0      1.0
#
#      altprc   spread    altprcdt      retx
# 0 -2.562500      NaN  1986-01-07       NaN
# 1 -4.375000  0.25000  1986-01-31       NaN
# 2 -3.250000  0.25000  1986-02-28 -0.257143
# 3 -4.437500  0.12500  1986-03-31  0.365385
# 4 -4.000000  0.25000  1986-04-30 -0.098592
# 5 -3.109375  0.09375  1986-05-30 -0.222656
# 6 -3.093750  0.06250  1986-06-30 -0.005025
# 7 -2.843750  0.06250  1986-07-31 -0.080808
# 8 -1.093750  0.06250  1986-08-29 -0.615385
# 9 -1.031250  0.06250  1986-09-30 -0.057143
#
# [10 rows x 21 columns]

# %%
db.describe_table(library='crsp_a_stock', table='msf')
# Out:
# Approximately 4922867 rows in crsp_a_stock.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True  DOUBLE_PRECISION
# 2     permco      True  DOUBLE_PRECISION
# 3     issuno      True  DOUBLE_PRECISION
# 4      hexcd      True  DOUBLE_PRECISION
# 5     hsiccd      True  DOUBLE_PRECISION
# 6       date      True              DATE
# 7      bidlo      True  DOUBLE_PRECISION
# 8      askhi      True  DOUBLE_PRECISION
# 9        prc      True  DOUBLE_PRECISION
# 10       vol      True  DOUBLE_PRECISION
# 11       ret      True  DOUBLE_PRECISION
# 12       bid      True  DOUBLE_PRECISION
# 13       ask      True  DOUBLE_PRECISION
# 14    shrout      True  DOUBLE_PRECISION
# 15    cfacpr      True  DOUBLE_PRECISION
# 16   cfacshr      True  DOUBLE_PRECISION
# 17    altprc      True  DOUBLE_PRECISION
# 18    spread      True  DOUBLE_PRECISION
# 19  altprcdt      True              DATE
# 20      retx      True  DOUBLE_PRECISION
#
#                                     comment
# 0                              CUSIP Header
# 1                                    PERMNO
# 2                                    PERMCO
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18               Spread Between Bid and Ask
# 19                     Alternate Price Date
# 20                Returns without Dividends

# %%
#import wrds
#db = wrds.Connection()
apple = db.raw_sql("""select permno, date, prc, ret, shrout
                        from crsp_a_stock.msf
                       where permno = 14593
                         and date>='01/01/2021'
                         and date<='12/31/2021'
                   """,
                      date_cols=['date'])
apple
# Out:
#      permno       date         prc       ret      shrout
# 0   14593.0 2021-01-29  131.960007 -0.005502  16788096.0
# 1   14593.0 2021-02-26  121.260002 -0.079532  16788096.0
# 2   14593.0 2021-03-31  122.150002  0.007340  16686305.0
# 3   14593.0 2021-04-30  131.460007  0.076218  16687631.0
# 4   14593.0 2021-05-28  124.610001 -0.050434  16687631.0
# 5   14593.0 2021-06-30  136.960007  0.099109  16556942.0
# 6   14593.0 2021-07-30  145.860001  0.064982  16530166.0
# 7   14593.0 2021-08-31  151.830002  0.042438  16530166.0
# 8   14593.0 2021-09-30  141.500000 -0.068037  16426786.0
# 9   14593.0 2021-10-29  149.800003  0.058657  16406397.0
# 10  14593.0 2021-11-30  165.300003  0.104940  16406397.0
# 11  14593.0 2021-12-31  177.570007  0.074229  16344923.0

# %%
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
#import wrds
#db = wrds.Connection()
apple_ibm = db.raw_sql("""select permco, permno, date, prc, ret, shrout
                            from crsp_a_stock.msf
                         --where permno = 14593
                           where permno in ('14593', '12490')
                             and date>='01/01/2021'
                             and date<='12/31/2021'
                       """,
                       date_cols=['date'])
apple_ibm
# Out:
#      permco   permno       date         prc       ret      shrout
# 0   20990.0  12490.0 2021-01-29  119.110001 -0.053781    891057.0
# 1   20990.0  12490.0 2021-02-26  118.930000  0.012174    893594.0
# 2   20990.0  12490.0 2021-03-31  133.259995  0.120491    893594.0
# 3   20990.0  12490.0 2021-04-30  141.880005  0.064686    893523.0
# 4   20990.0  12490.0 2021-05-28  143.740005  0.024669    893523.0
# 5   20990.0  12490.0 2021-06-30  146.589996  0.019827    893523.0
# 6   20990.0  12490.0 2021-07-30  140.960007 -0.038406    896320.0
# 7   20990.0  12490.0 2021-08-31  140.339996  0.007236    896320.0
# 8   20990.0  12490.0 2021-09-30  138.929993 -0.010047    896320.0
# 9   20990.0  12490.0 2021-10-29  125.099998 -0.099546    896320.0
# 10  20990.0  12490.0 2021-11-30  117.099998 -0.009401    896800.0
# 11  20990.0  12490.0 2021-12-31  133.660004  0.141418    896800.0
# 12      7.0  14593.0 2021-01-29  131.960007 -0.005502  16788096.0
# 13      7.0  14593.0 2021-02-26  121.260002 -0.079532  16788096.0
# 14      7.0  14593.0 2021-03-31  122.150002  0.007340  16686305.0
# 15      7.0  14593.0 2021-04-30  131.460007  0.076218  16687631.0
# 16      7.0  14593.0 2021-05-28  124.610001 -0.050434  16687631.0
# 17      7.0  14593.0 2021-06-30  136.960007  0.099109  16556942.0
# 18      7.0  14593.0 2021-07-30  145.860001  0.064982  16530166.0
# 19      7.0  14593.0 2021-08-31  151.830002  0.042438  16530166.0
# 20      7.0  14593.0 2021-09-30  141.500000 -0.068037  16426786.0
# 21      7.0  14593.0 2021-10-29  149.800003  0.058657  16406397.0
# 22      7.0  14593.0 2021-11-30  165.300003  0.104940  16406397.0
# 23      7.0  14593.0 2021-12-31  177.570007  0.074229  16344923.0

# %%
apple.to_csv('apple_24_0909.csv')
#apple_ibm.to_csv('apple_ibm_24_0909.csv')

# %%
import pandas as pd
df = pd.read_csv('apple_24_0909.csv')
print(df.to_string())
# Out:
#     Unnamed: 0   permno        date         prc       ret      shrout
# 0            0  14593.0  2021-01-29  131.960007 -0.005502  16788096.0
# 1            1  14593.0  2021-02-26  121.260002 -0.079532  16788096.0
# 2            2  14593.0  2021-03-31  122.150002  0.007340  16686305.0
# 3            3  14593.0  2021-04-30  131.460007  0.076218  16687631.0
# 4            4  14593.0  2021-05-28  124.610001 -0.050434  16687631.0
# 5            5  14593.0  2021-06-30  136.960007  0.099109  16556942.0
# 6            6  14593.0  2021-07-30  145.860001  0.064982  16530166.0
# 7            7  14593.0  2021-08-31  151.830002  0.042438  16530166.0
# 8            8  14593.0  2021-09-30  141.500000 -0.068037  16426786.0
# 9            9  14593.0  2021-10-29  149.800003  0.058657  16406397.0
# 10          10  14593.0  2021-11-30  165.300003  0.104940  16406397.0
# 11          11  14593.0  2021-12-31  177.570007  0.074229  16344923.0

# %%
#import wrds
#db = wrds.Connection()
apple = db.raw_sql("""select count (*)
                        from crsp_a_stock.msf
                      """)
apple
# Out:
#      count
# 0  4922867

# %%
#db.list_tables(library='crsp_q_mutualfunds')
#db.describe_table(library='crsp_q_mutualfunds', table='fund_summary2')

mfs = db.raw_sql("""--select *
                      select fund_name, ticker, first_offer_dt, mgmt_fee
                        from crsp_q_mutualfunds.fund_summary2""")
mfs
# Out:
#                                                 fund_name ticker  \
# 0                          AARP Income Tr:Bond for Income  AABIX
# 1                          AARP Income Tr:Bond for Income  AABIX
# 2                          AARP Income Tr:Bond for Income  AABIX
# 3                          AARP Income Tr:Bond for Income  AABIX
# 4                          AARP Income Tr:Bond for Income  AABIX
# ...                                                   ...    ...
# 155177  Franklin Templeton ETF Trust: Franklin Income ...   INCM
# 155178  ETF Series Solutions: LHA Risk-Managed Income ETF   RMIF
# 155179   Volatility Shares Trust: 2x Bitcoin Strategy ETF   BITX
# 155180  RBC Funds Trust: RBC US Government Money Marke...  RGMXX
# 155181                    Tidal Trust II: Clouty Tune ETF   TUNE
#
#        first_offer_dt  mgmt_fee
# 0          1997-02-01    -0.282
# 1          1997-02-01     0.084
# 2          1997-02-01     0.084
# 3          1997-02-01     0.084
# 4          1997-02-01     0.084
# ...               ...       ...
# 155177     2023-06-06       NaN
# 155178     2023-06-08       NaN
# 155179     2023-06-26       NaN
# 155180     2023-06-08       NaN
# 155181     2023-06-21       NaN
#
# [2655182 rows x 4 columns]

# %%
#db.list_tables(library='crsp_q_mutualfunds')
#db.describe_table(library='crsp_q_mutualfunds', table='fund_summary2')

mfs = db.raw_sql("""--select *
                      select fund_name, ticker, first_offer_dt, mgmt_fee
                        from crsp_q_mutualfunds.fund_summary2 
                       LIMIT 03
                 """)
mfs
# Out:
#                         fund_name ticker first_offer_dt  mgmt_fee
# 0  AARP Income Tr:Bond for Income  AABIX     1997-02-01    -0.282
# 1  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084
# 2  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084

# %%
#import wrds
#db = wrds.Connection()
#db.get_table(library='crsp_q_mutualfunds', table='fund_summary2', obs=3)
db.get_table(library='crsp_q_mutualfunds', table='fund_summary2', columns = ['fund_name', 'ticker', 'first_offer_dt', 'mgmt_fee'], obs=3)
# Out:
#                         fund_name ticker first_offer_dt  mgmt_fee
# 0  AARP Income Tr:Bond for Income  AABIX     1997-02-01    -0.282
# 1  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084
# 2  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084

# %%
#import wrds
#db = wrds.Connection()
c = db.raw_sql(""" select ticker, comnam, permno, ncusip, namedt, nameenddt
                     from crsp.stocknames """, date_cols=['namedt', 'nameenddt'])

c = c.loc[c.ticker.notnull()].sort_values(by=['permno','ticker','namedt'])
c
# Out:
#       ticker                     comnam   permno    ncusip     namedt  \
# 0      OMFGA  OPTIMUM MANUFACTURING INC  10000.0  68391610 1986-01-07
# 4       EGAS                 ENERGY INC  10001.0  29269V10 2009-08-04
# 5       EGAS                 ENERGY INC  10001.0  29269V10 2009-12-18
# 6       EGAS            GAS NATURAL INC  10001.0  36720410 2010-07-09
# 2       EWST            ENERGY WEST INC  10001.0  29274A10 1993-11-22
# ...      ...                        ...      ...       ...        ...
# 79032   VLTC               VOLTARI CORP  93433.0  92870X30 2013-04-24
# 79033   SANW              S & W SEED CO  93434.0  78513510 2010-06-14
# 79034   SCEI      SINO CLEAN ENERGY INC  93435.0  82936G20 2010-06-14
# 79035   TSLA           TESLA MOTORS INC  93436.0  88160R10 2010-06-29
# 79036   TSLA                  TESLA INC  93436.0  88160R10 2017-02-02
#
#        nameenddt
# 0     1987-06-11
# 4     2009-12-17
# 5     2010-07-08
# 6     2017-08-03
# 2     2008-02-04
# ...          ...
# 79032 2016-12-22
# 79033 2022-12-30
# 79034 2012-05-18
# 79035 2017-02-01
# 79036 2022-12-30
#
# [74108 rows x 6 columns]

# %%
#import wrds
#db = wrds.Connection()
c = db.raw_sql(""" select ticker, comnam, permno, ncusip, namedt, nameenddt
                     from crsp.stocknames
                    where ticker is not null
                 order by permno, namedt, ticker """)
c
# Out:
#       ticker                     comnam   permno    ncusip      namedt  \
# 0      OMFGA  OPTIMUM MANUFACTURING INC  10000.0  68391610  1986-01-07
# 1       GFGC         GREAT FALLS GAS CO  10001.0  39040610  1986-01-09
# 2       EWST            ENERGY WEST INC  10001.0  29274A10  1993-11-22
# 3       EWST            ENERGY WEST INC  10001.0  29274A20  2008-02-05
# 4       EGAS                 ENERGY INC  10001.0  29269V10  2009-08-04
# ...      ...                        ...      ...       ...         ...
# 74103   VLTC               VOLTARI CORP  93433.0  92870X30  2013-04-24
# 74104   SANW              S & W SEED CO  93434.0  78513510  2010-06-14
# 74105   SCEI      SINO CLEAN ENERGY INC  93435.0  82936G20  2010-06-14
# 74106   TSLA           TESLA MOTORS INC  93436.0  88160R10  2010-06-29
# 74107   TSLA                  TESLA INC  93436.0  88160R10  2017-02-02
#
#         nameenddt
# 0      1987-06-11
# 1      1993-11-21
# 2      2008-02-04
# 3      2009-08-03
# 4      2009-12-17
# ...           ...
# 74103  2016-12-22
# 74104  2022-12-30
# 74105  2012-05-18
# 74106  2017-02-01
# 74107  2022-12-30
#
# [74108 rows x 6 columns]

# %%
apple2 = db.raw_sql("""select
                              --permno,
                              date,
                              --prc,
                              ret--,
                              --shrout
                        from crsp_a_stock.msf
                       where permno = 14593
                         and date>='01/01/1980'
                         and date<='12/31/2022'
                    order by date""",
                         date_cols=['date'], index_col=['date'])
apple2
# Out:
#                  ret
# date
# 1980-11-28       NaN
# 1980-12-31       NaN
# 1981-01-30 -0.170018
# 1981-02-27 -0.061674
# 1981-03-31 -0.075117
# ...              ...
# 2022-08-31 -0.031137
# 2022-09-30 -0.120977
# 2022-10-31  0.109551
# 2022-11-30 -0.033129
# 2022-12-30 -0.122273
#
# [506 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(apple2)
plt.xlabel('date')
plt.ylabel('ret')
plt.show()

# %%
#db.list_libraries()
#db.list_tables()
#db.describe_table()
#db.get_row_count()
#db.get_table()
#db.raw_sql()

# %%
help(db.list_libraries)
#help(db.list_tables)
#help(db.describe_table)
#help(db.get_row_count)
#help(db.get_table)
#help(db.raw_sql)
# Out:
# Help on method list_libraries in module wrds.sql:
#
# list_libraries() method of wrds.sql.Connection instance
#     Return all the libraries (schemas) the user can access.
#
#     :rtype: list
#
#     Usage::
#     >>> db.list_libraries()
#     ['aha', 'audit', 'block', 'boardex', ...]

# %%
#help(db.list_libraries)
#help(db.list_tables)
#help(db.describe_table)
#help(db.get_row_count)
#help(db.get_table)
help(db.raw_sql)
# Out:
# Help on method raw_sql in module wrds.sql:
#
# raw_sql(sql, coerce_float=True, date_cols=None, index_col=None, params=None, chunksize=500000, return_iter=False) method of wrds.sql.Connection instance
#     Queries the database using a raw SQL string.
#
#     :param sql: SQL code in string object.
#     :param coerce_float: (optional) boolean, default: True
#         Attempt to convert values to non-string, non-numeric objects
#         to floating point. Can result in loss of precision.
#     :param date_cols: (optional) list or dict, default: None
#         - List of column names to parse as date
#         - Dict of ``{column_name: format string}`` where
#             format string is:
#               strftime compatible in case of parsing string times or
#               is one of (D, s, ns, ms, us) in case of parsing
#                 integer timestamps
#         - Dict of ``{column_name: arg dict}``,
#             where the arg dict corresponds to the keyword arguments of
#               :func:`pandas.to_datetime`
#     :param index_col: (optional) string or list of strings,
#       default: None
#         Column(s) to set as index(MultiIndex)
#     :param params: parameters to SQL query, if parameterized.
#     :param chunksize: (optional) integer or None default: 500000
#         Process query in chunks of this size. Smaller chunksizes can save
#         a considerable amount of memory while query is being processed.
#         Set to None run query w/o chunking.
#     :param return_iter: (optional) boolean, default:False
#         When chunksize is not None, return an iterator where chunksize
#         number of rows is included in each chunk.
#
#     :rtype: pandas.DataFrame or or Iterator[pandas.DataFrame]
#
#
#     Usage ::
#     # Basic Usage
#     >>> data = db.raw_sql('select cik, fdate, coname from wrdssec_all.dforms;', date_cols=['fdate'], index_col='cik')
#     >>> data.head()
#         cik        fdate       coname
#         0000000003 1995-02-15  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1996-02-14  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1997-02-19  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1998-03-02  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y...
#         0000000003 1998-03-10  DEFINED ASSET FUNDS MUNICIPAL INVT TR FD NEW Y..
#         ...
#
#     # Parameterized SQL query
#     >>> parm = {'syms': ('A', 'AA', 'AAPL'), 'num_shares': 50000}
#     >>> data = db.raw_sql('select * from taqmsec.ctm_20030910 where sym_root in %(syms)s and size > %(num_shares)s', params=parm)
#     >>> data.head()
#               date           time_m ex sym_root sym_suffix tr_scond      size   price tr_stopind tr_corr     tr_seqnum tr_source tr_rf
#         2003-09-10  11:02:09.485000  T        A       None     None  211400.0  25.350          N      00  1.929952e+15         C  None
#         2003-09-10  11:04:29.508000  N        A       None     None   55500.0  25.180          N      00  1.929952e+15         C  None
#         2003-09-10  15:08:21.155000  N        A       None     None   50500.0  24.470          N      00  1.929967e+15         C  None
#         2003-09-10  16:10:35.522000  T        A       None        B   71900.0  24.918          N      00  1.929970e+15         C  None
#         2003-09-10  09:35:20.709000  N       AA       None     None  108100.0  28.200          N      00  1.929947e+15         C  None

# %%
###

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks

# %%
###

# %%
db.describe_table('crsp_a_stock','dsedelist')
# Out:
# Approximately 36974 rows in crsp_a_stock.dsedelist.
#       name  nullable              type  \
# 0   permno      True  DOUBLE_PRECISION
# 1   dlstdt      True              DATE
# 2   dlstcd      True  DOUBLE_PRECISION
# 3   nwperm      True  DOUBLE_PRECISION
# 4   nwcomp      True  DOUBLE_PRECISION
# 5   nextdt      True              DATE
# 6    dlamt      True  DOUBLE_PRECISION
# 7   dlretx      True  DOUBLE_PRECISION
# 8    dlprc      True  DOUBLE_PRECISION
# 9    dlpdt      True              DATE
# 10   dlret      True  DOUBLE_PRECISION
# 11  permco      True  DOUBLE_PRECISION
# 12  compno      True  DOUBLE_PRECISION
# 13  issuno      True  DOUBLE_PRECISION
# 14   hexcd      True  DOUBLE_PRECISION
# 15  hsiccd      True  DOUBLE_PRECISION
# 16   cusip      True        VARCHAR(8)
# 17  acperm      True  DOUBLE_PRECISION
# 18  accomp      True  DOUBLE_PRECISION
#
#                                     comment
# 0                                    PERMNO
# 1                            Delisting Date
# 2                            Delisting Code
# 3                                New PERMNO
# 4                                New PERMCO
# 5                 Delisting Next Price Date
# 6                          Delisting Amount
# 7        Delisting Return Without Dividends
# 8                           Delisting Price
# 9                     Delisting Amount Date
# 10                         Delisting Return
# 11                                   PERMCO
# 12                    Nasdaq Company Number
# 13                      Nasdaq Issue Number
# 14                     Exchange Code Header
# 15  Standard Industrial Classification Code
# 16                             CUSIP Header
# 17                                     None
# 18                                     None

# %%
crsp_dsedelist = db.raw_sql("""
                       select *
                         from crsp_a_stock.dsedelist
                        where permno in
                              (
                              '11081',
                              '13430',
                              '14295',
                              '91212'
                               )
                            """)
crsp_dsedelist

#11081 - Dell
#13430 - Burger King Worldwide Inc
#14295 - Twitter
#91212 - Burger King Holdings Inc
# Out:
#     permno      dlstdt  dlstcd   nwperm   nwcomp nextdt      dlamt    dlretx  \
# 0  11081.0  2013-10-29   233.0      0.0      0.0   None  13.880000  0.001443
# 1  13430.0  2014-12-12   242.0  15113.0  55137.0   None  35.309940 -0.005354
# 2  14295.0  2022-10-27   233.0      0.0      0.0   None  54.200001  0.009311
# 3  91212.0  2010-10-19   233.0      0.0      0.0   None  24.000000  0.000417
#
#    dlprc       dlpdt     dlret   permco      compno   issuno  hexcd  hsiccd  \
# 0    0.0  2013-10-30  0.001443   9833.0  70015042.0  13114.0    3.0  3570.0
# 1    0.0  2014-12-15 -0.005354  54100.0         0.0      0.0    1.0  5812.0
# 2    0.0  2022-10-28  0.009311  54638.0         0.0      0.0    1.0  7375.0
# 3    0.0  2010-10-20  0.000417  50692.0         0.0      0.0    1.0  5812.0
#
#       cusip acperm accomp
# 0  24702R10   None   None
# 1  12122010   None   None
# 2  90184L10   None   None
# 3  12120820   None   None

# %%
#https://abcnews.go.com/Business/timeline-elon-musks-tumultuous-twitter-acquisition-attempt/story?id=86611191

# %%
db.describe_table('crsp_a_stock','dse')
# Out:
# Approximately 12346611 rows in crsp_a_stock.dse.
#         name  nullable              type  \
# 0      event      True        VARCHAR(8)
# 1       date      True              DATE
# 2     hsicmg      True  DOUBLE_PRECISION
# 3     hsicig      True  DOUBLE_PRECISION
# 4     comnam      True       VARCHAR(32)
# 5      cusip      True        VARCHAR(8)
# 6     dclrdt      True              DATE
# 7      dlamt      True  DOUBLE_PRECISION
# 8      dlpdt      True              DATE
# 9     dlstcd      True  DOUBLE_PRECISION
# 10    hsiccd      True  DOUBLE_PRECISION
# 11    issuno      True  DOUBLE_PRECISION
# 12    ncusip      True        VARCHAR(8)
# 13    nextdt      True              DATE
# 14     paydt      True              DATE
# 15    rcrddt      True              DATE
# 16    shrcls      True        VARCHAR(1)
# 17    shrflg      True  DOUBLE_PRECISION
# 18    ticker      True        VARCHAR(5)
# 19    permno      True  DOUBLE_PRECISION
# 20  nameendt      True              DATE
# 21     shrcd      True  DOUBLE_PRECISION
# 22    exchcd      True  DOUBLE_PRECISION
# 23     siccd      True  DOUBLE_PRECISION
# 24   tsymbol      True       VARCHAR(10)
# 25     naics      True        VARCHAR(7)
# 26  primexch      True        VARCHAR(1)
# 27   trdstat      True        VARCHAR(1)
# 28   secstat      True        VARCHAR(1)
# 29    permco      True  DOUBLE_PRECISION
# 30    compno      True  DOUBLE_PRECISION
# 31     hexcd      True  DOUBLE_PRECISION
# 32    distcd      True  DOUBLE_PRECISION
# 33    divamt      True  DOUBLE_PRECISION
# 34     facpr      True  DOUBLE_PRECISION
# 35    facshr      True  DOUBLE_PRECISION
# 36    acperm      True  DOUBLE_PRECISION
# 37    accomp      True  DOUBLE_PRECISION
# 38    nwperm      True  DOUBLE_PRECISION
# 39    nwcomp      True  DOUBLE_PRECISION
# 40    dlretx      True  DOUBLE_PRECISION
# 41     dlprc      True  DOUBLE_PRECISION
# 42     dlret      True  DOUBLE_PRECISION
# 43    shrout      True  DOUBLE_PRECISION
# 44  shrenddt      True              DATE
# 45    trtscd      True  DOUBLE_PRECISION
# 46  trtsendt      True              DATE
# 47    nmsind      True  DOUBLE_PRECISION
# 48     mmcnt      True  DOUBLE_PRECISION
# 49    nsdinx      True  DOUBLE_PRECISION
#
#                                               comment
# 0                                          Event Name
# 1   Date of Observation. NAMEDT of NAMES events; e...
# 2                              Header SIC Major Gorup
# 3                           Header SIC Industry Group
# 4                                        Company Name
# 5                                    CUSIP Identifier
# 6                                    Declaration Date
# 7                              Amount After Delisting
# 8                           Date of Delisting Payment
# 9                                      Delisting Code
# 10                                     Header SIC Cde
# 11                            Nasdaq Issue Identifier
# 12                                        Names CUSIP
# 13                 Date of Next Available Information
# 14                                       Payment Date
# 15                                        Record Date
# 16                                        Share Class
# 17                       Number of Shares Outstanding
# 18                             Exchange Ticker Symbol
# 19                                             PERMNO
# 20                                  Names Ending Date
# 21                                         Share Code
# 22                                      Exchange Code
# 23            Standard Industrial Classification Code
# 24                                     Trading Symbol
# 25      North American Industry Classification System
# 26                                   Primary Exchange
# 27                                     Trading Status
# 28                                    Security Status
# 29                                             PERMCO
# 30                              Nasdaq Company Number
# 31                               Exchange Code Header
# 32                                  Distribution Code
# 33                               Dividend Cash Amount
# 34                             Factor to Adjust Price
# 35                            Factor to Adjust Shares
# 36                                   Acquiring PERMNO
# 37                                   Acquiring PERMCO
# 38                                         New PERMNO
# 39                                         New PERMCO
# 40                 Delisting Return Without Dividends
# 41                                    Delisting Price
# 42                                   Delisting Return
# 43                                 Shares Outstanding
# 44                        Shares Observation End Date
# 45                                 Nasdaq Traits Code
# 46                             Nasdaq Traits End Date
# 47                   Nasdaq National Market Indicator
# 48                                 Market Maker Count
# 49                                    Nasd Index Code

# %%
crsp_dse = db.raw_sql("""
                       select * from crsp_a_stock.dse
                        where permno in
                                (
                                '11081',
                                '13430',
                                '14295',
                                '91212'
                                )
                          and event = 'DELIST'
                      """)
crsp_dse
# Out:
#     event        date  hsicmg  hsicig comnam     cusip dclrdt      dlamt  \
# 0  DELIST  2013-10-29    35.0   357.0   None  24702R10   None  13.880000
# 1  DELIST  2014-12-12    58.0   581.0   None  12122010   None  35.309940
# 2  DELIST  2022-10-27    73.0   737.0   None  90184L10   None  54.200001
# 3  DELIST  2010-10-19    58.0   581.0   None  12120820   None  24.000000
#
#         dlpdt  dlstcd  ...    dlretx  dlprc     dlret shrout shrenddt trtscd  \
# 0  2013-10-30   233.0  ...  0.001443    0.0  0.001443   None     None   None
# 1  2014-12-15   242.0  ... -0.005354    0.0 -0.005354   None     None   None
# 2  2022-10-28   233.0  ...  0.009311    0.0  0.009311   None     None   None
# 3  2010-10-20   233.0  ...  0.000417    0.0  0.000417   None     None   None
#
#   trtsendt nmsind mmcnt  nsdinx
# 0     None   None  None    None
# 1     None   None  None    None
# 2     None   None  None    None
# 3     None   None  None    None
#
# [4 rows x 50 columns]

# %%
#CAUTION
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
display(crsp_dsedelist)
# Out:
#     permno      dlstdt  dlstcd   nwperm   nwcomp nextdt      dlamt    dlretx  \
# 0  11081.0  2013-10-29   233.0      0.0      0.0   None  13.880000  0.001443
# 1  13430.0  2014-12-12   242.0  15113.0  55137.0   None  35.309940 -0.005354
# 2  14295.0  2022-10-27   233.0      0.0      0.0   None  54.200001  0.009311
# 3  91212.0  2010-10-19   233.0      0.0      0.0   None  24.000000  0.000417
#
#    dlprc       dlpdt     dlret   permco      compno   issuno  hexcd  hsiccd  \
# 0    0.0  2013-10-30  0.001443   9833.0  70015042.0  13114.0    3.0  3570.0
# 1    0.0  2014-12-15 -0.005354  54100.0         0.0      0.0    1.0  5812.0
# 2    0.0  2022-10-28  0.009311  54638.0         0.0      0.0    1.0  7375.0
# 3    0.0  2010-10-20  0.000417  50692.0         0.0      0.0    1.0  5812.0
#
#       cusip acperm accomp
# 0  24702R10   None   None
# 1  12122010   None   None
# 2  90184L10   None   None
# 3  12120820   None   None

# %% [markdown]
# ### TAQ

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
taq = [x for x in lib if 'taq' in x]
taq
# Out:
# ['taqm_2003',
#  'taqm_2004',
#  'taqm_2005',
#  'taqm_2006',
#  'taqm_2007',
#  'taqm_2008',
#  'taqm_2009',
#  'taqm_2010',
#  'taqm_2011',
#  'taqm_2012',
#  'taqm_2013',
#  'taqm_2014',
#  'taqm_2015',
#  'taqm_2016',
#  'taqm_2017',
#  'taqm_2018',
#  'taqm_2019',
#  'taqm_2020',
#  'taqm_2021',
#  'taqmsamp',
#  'taqmsamp_all',
#  'taqmsec',
#  'taqsamp',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm']

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='taqm_2020')
tables
# Out:
# ['complete_nbbo_2020',
#  'complete_nbbo_20200102',
#  'complete_nbbo_20200103',
#  'complete_nbbo_20200106',
#  'complete_nbbo_20200107',
#  'complete_nbbo_20200108',
#  'complete_nbbo_20200109',
#  'complete_nbbo_20200110',
#  'complete_nbbo_20200113',
#  'complete_nbbo_20200114',
#  'complete_nbbo_20200115',
#  'complete_nbbo_20200116',
#  'complete_nbbo_20200117',
#  'complete_nbbo_20200121',
#  'complete_nbbo_20200122',
#  'complete_nbbo_20200123',
#  'complete_nbbo_20200124',
#  'complete_nbbo_20200127',
#  'complete_nbbo_20200128',
#  'complete_nbbo_20200129',
#  'complete_nbbo_20200130',
#  'complete_nbbo_20200131',
#  'complete_nbbo_20200203',
#  'complete_nbbo_20200204',
#  'complete_nbbo_20200205',
#  'complete_nbbo_20200206',
#  'complete_nbbo_20200207',
#  'complete_nbbo_20200210',
#  'complete_nbbo_20200211',
#  'complete_nbbo_20200212',
#  'complete_nbbo_20200213',
#  'complete_nbbo_20200214',
#  'complete_nbbo_20200218',
#  'complete_nbbo_20200219',
#  'complete_nbbo_20200220',
#  'complete_nbbo_20200221',
#  'complete_nbbo_20200224',
#  'complete_nbbo_20200225',
#  'complete_nbbo_20200226',
#  'complete_nbbo_20200227',
#  'complete_nbbo_20200228',
#  'complete_nbbo_20200302',
#  'complete_nbbo_20200303',
#  'complete_nbbo_20200304',
#  'complete_nbbo_20200305',
#  'complete_nbbo_20200306',
#  'complete_nbbo_20200309',
#  'complete_nbbo_20200310',
#  'complete_nbbo_20200311',
#  'complete_nbbo_20200312',
#  'complete_nbbo_20200313',
#  'complete_nbbo_20200316',
#  'complete_nbbo_20200317',
#  'complete_nbbo_20200318',
#  'complete_nbbo_20200319',
#  'complete_nbbo_20200320',
#  'complete_nbbo_20200323',
#  'complete_nbbo_20200324',
#  'complete_nbbo_20200325',
#  'complete_nbbo_20200326',
#  'complete_nbbo_20200327',
#  'complete_nbbo_20200330',
#  'complete_nbbo_20200331',
#  'complete_nbbo_20200401',
#  'complete_nbbo_20200402',
#  'complete_nbbo_20200403',
#  'complete_nbbo_20200406',
#  'complete_nbbo_20200407',
#  'complete_nbbo_20200408',
#  'complete_nbbo_20200409',
#  'complete_nbbo_20200413',
#  'complete_nbbo_20200414',
#  'complete_nbbo_20200415',
#  'complete_nbbo_20200416',
#  'complete_nbbo_20200417',
#  'complete_nbbo_20200420',
#  'complete_nbbo_20200421',
#  'complete_nbbo_20200422',
#  'complete_nbbo_20200423',
#  'complete_nbbo_20200424',
#  'complete_nbbo_20200427',
#  'complete_nbbo_20200428',
#  'complete_nbbo_20200429',
#  'complete_nbbo_20200430',
#  'complete_nbbo_20200501',
#  'complete_nbbo_20200504',
#  'complete_nbbo_20200505',
#  'complete_nbbo_20200506',
#  'complete_nbbo_20200507',
#  'complete_nbbo_20200508',
#  'complete_nbbo_20200511',
#  'complete_nbbo_20200512',
#  'complete_nbbo_20200513',
#  'complete_nbbo_20200514',
#  'complete_nbbo_20200515',
#  'complete_nbbo_20200518',
#  'complete_nbbo_20200519',
#  'complete_nbbo_20200520',
#  'complete_nbbo_20200521',
#  'complete_nbbo_20200522',
#  'complete_nbbo_20200526',
#  'complete_nbbo_20200527',
#  'complete_nbbo_20200528',
#  'complete_nbbo_20200529',
#  'complete_nbbo_20200601',
#  'complete_nbbo_20200602',
#  'complete_nbbo_20200603',
#  'complete_nbbo_20200604',
#  'complete_nbbo_20200605',
#  'complete_nbbo_20200608',
#  'complete_nbbo_20200609',
#  'complete_nbbo_20200610',
#  'complete_nbbo_20200611',
#  'complete_nbbo_20200612',
#  'complete_nbbo_20200615',
#  'complete_nbbo_20200616',
#  'complete_nbbo_20200617',
#  'complete_nbbo_20200618',
#  'complete_nbbo_20200619',
#  'complete_nbbo_20200622',
#  'complete_nbbo_20200623',
#  'complete_nbbo_20200624',
#  'complete_nbbo_20200625',
#  'complete_nbbo_20200626',
#  'complete_nbbo_20200629',
#  'complete_nbbo_20200630',
#  'complete_nbbo_20200701',
#  'complete_nbbo_20200702',
#  'complete_nbbo_20200706',
#  'complete_nbbo_20200707',
#  'complete_nbbo_20200708',
#  'complete_nbbo_20200709',
#  'complete_nbbo_20200710',
#  'complete_nbbo_20200713',
#  'complete_nbbo_20200714',
#  'complete_nbbo_20200715',
#  'complete_nbbo_20200716',
#  'complete_nbbo_20200717',
#  'complete_nbbo_20200720',
#  'complete_nbbo_20200721',
#  'complete_nbbo_20200722',
#  'complete_nbbo_20200723',
#  'complete_nbbo_20200724',
#  'complete_nbbo_20200727',
#  'complete_nbbo_20200728',
#  'complete_nbbo_20200729',
#  'complete_nbbo_20200730',
#  'complete_nbbo_20200731',
#  'complete_nbbo_20200803',
#  'complete_nbbo_20200804',
#  'complete_nbbo_20200805',
#  'complete_nbbo_20200806',
#  'complete_nbbo_20200807',
#  'complete_nbbo_20200810',
#  'complete_nbbo_20200811',
#  'complete_nbbo_20200812',
#  'complete_nbbo_20200813',
#  'complete_nbbo_20200814',
#  'complete_nbbo_20200817',
#  'complete_nbbo_20200818',
#  'complete_nbbo_20200819',
#  'complete_nbbo_20200820',
#  'complete_nbbo_20200821',
#  'complete_nbbo_20200824',
#  'complete_nbbo_20200825',
#  'complete_nbbo_20200826',
#  'complete_nbbo_20200827',
#  'complete_nbbo_20200828',
#  'complete_nbbo_20200831',
#  'complete_nbbo_20200901',
#  'complete_nbbo_20200902',
#  'complete_nbbo_20200903',
#  'complete_nbbo_20200904',
#  'complete_nbbo_20200908',
#  'complete_nbbo_20200909',
#  'complete_nbbo_20200910',
#  'complete_nbbo_20200911',
#  'complete_nbbo_20200914',
#  'complete_nbbo_20200915',
#  'complete_nbbo_20200916',
#  'complete_nbbo_20200917',
#  'complete_nbbo_20200918',
#  'complete_nbbo_20200921',
#  'complete_nbbo_20200922',
#  'complete_nbbo_20200923',
#  'complete_nbbo_20200924',
#  'complete_nbbo_20200925',
#  'complete_nbbo_20200928',
#  'complete_nbbo_20200929',
#  'complete_nbbo_20200930',
#  'complete_nbbo_20201001',
#  'complete_nbbo_20201002',
#  'complete_nbbo_20201005',
#  'complete_nbbo_20201006',
#  'complete_nbbo_20201007',
#  'complete_nbbo_20201008',
#  'complete_nbbo_20201009',
#  'complete_nbbo_20201012',
#  'complete_nbbo_20201013',
#  'complete_nbbo_20201014',
#  'complete_nbbo_20201015',
#  'complete_nbbo_20201016',
#  'complete_nbbo_20201019',
#  'complete_nbbo_20201020',
#  'complete_nbbo_20201021',
#  'complete_nbbo_20201022',
#  'complete_nbbo_20201023',
#  'complete_nbbo_20201026',
#  'complete_nbbo_20201027',
#  'complete_nbbo_20201028',
#  'complete_nbbo_20201029',
#  'complete_nbbo_20201030',
#  'complete_nbbo_20201102',
#  'complete_nbbo_20201103',
#  'complete_nbbo_20201104',
#  'complete_nbbo_20201105',
#  'complete_nbbo_20201106',
#  'complete_nbbo_20201109',
#  'complete_nbbo_20201110',
#  'complete_nbbo_20201111',
#  'complete_nbbo_20201112',
#  'complete_nbbo_20201113',
#  'complete_nbbo_20201116',
#  'complete_nbbo_20201117',
#  'complete_nbbo_20201118',
#  'complete_nbbo_20201119',
#  'complete_nbbo_20201120',
#  'complete_nbbo_20201123',
#  'complete_nbbo_20201124',
#  'complete_nbbo_20201125',
#  'complete_nbbo_20201127',
#  'complete_nbbo_20201130',
#  'complete_nbbo_20201201',
#  'complete_nbbo_20201202',
#  'complete_nbbo_20201203',
#  'complete_nbbo_20201204',
#  'complete_nbbo_20201207',
#  'complete_nbbo_20201208',
#  'complete_nbbo_20201209',
#  'complete_nbbo_20201210',
#  'complete_nbbo_20201211',
#  'complete_nbbo_20201214',
#  'complete_nbbo_20201215',
#  'complete_nbbo_20201216',
#  'complete_nbbo_20201217',
#  'complete_nbbo_20201218',
#  'complete_nbbo_20201221',
#  'complete_nbbo_20201222',
#  'complete_nbbo_20201223',
#  'complete_nbbo_20201224',
#  'complete_nbbo_20201228',
#  'complete_nbbo_20201229',
#  'complete_nbbo_20201230',
#  'complete_nbbo_20201231',
#  'cqm_2020',
#  'cqm_20200102',
#  'cqm_20200103',
#  'cqm_20200106',
#  'cqm_20200107',
#  'cqm_20200108',
#  'cqm_20200109',
#  'cqm_20200110',
#  'cqm_20200113',
#  'cqm_20200114',
#  'cqm_20200115',
#  'cqm_20200116',
#  'cqm_20200117',
#  'cqm_20200121',
#  'cqm_20200122',
#  'cqm_20200123',
#  'cqm_20200124',
#  'cqm_20200127',
#  'cqm_20200128',
#  'cqm_20200129',
#  'cqm_20200130',
#  'cqm_20200131',
#  'cqm_20200203',
#  'cqm_20200204',
#  'cqm_20200205',
#  'cqm_20200206',
#  'cqm_20200207',
#  'cqm_20200210',
#  'cqm_20200211',
#  'cqm_20200212',
#  'cqm_20200213',
#  'cqm_20200214',
#  'cqm_20200218',
#  'cqm_20200219',
#  'cqm_20200220',
#  'cqm_20200221',
#  'cqm_20200224',
#  'cqm_20200225',
#  'cqm_20200226',
#  'cqm_20200227',
#  'cqm_20200228',
#  'cqm_20200302',
#  'cqm_20200303',
#  'cqm_20200304',
#  'cqm_20200305',
#  'cqm_20200306',
#  'cqm_20200309',
#  'cqm_20200310',
#  'cqm_20200311',
#  'cqm_20200312',
#  'cqm_20200313',
#  'cqm_20200316',
#  'cqm_20200317',
#  'cqm_20200318',
#  'cqm_20200319',
#  'cqm_20200320',
#  'cqm_20200323',
#  'cqm_20200324',
#  'cqm_20200325',
#  'cqm_20200326',
#  'cqm_20200327',
#  'cqm_20200330',
#  'cqm_20200331',
#  'cqm_20200401',
#  'cqm_20200402',
#  'cqm_20200403',
#  'cqm_20200406',
#  'cqm_20200407',
#  'cqm_20200408',
#  'cqm_20200409',
#  'cqm_20200413',
#  'cqm_20200414',
#  'cqm_20200415',
#  'cqm_20200416',
#  'cqm_20200417',
#  'cqm_20200420',
#  'cqm_20200421',
#  'cqm_20200422',
#  'cqm_20200423',
#  'cqm_20200424',
#  'cqm_20200427',
#  'cqm_20200428',
#  'cqm_20200429',
#  'cqm_20200430',
#  'cqm_20200501',
#  'cqm_20200504',
#  'cqm_20200505',
#  'cqm_20200506',
#  'cqm_20200507',
#  'cqm_20200508',
#  'cqm_20200511',
#  'cqm_20200512',
#  'cqm_20200513',
#  'cqm_20200514',
#  'cqm_20200515',
#  'cqm_20200518',
#  'cqm_20200519',
#  'cqm_20200520',
#  'cqm_20200521',
#  'cqm_20200522',
#  'cqm_20200526',
#  'cqm_20200527',
#  'cqm_20200528',
#  'cqm_20200529',
#  'cqm_20200601',
#  'cqm_20200602',
#  'cqm_20200603',
#  'cqm_20200604',
#  'cqm_20200605',
#  'cqm_20200608',
#  'cqm_20200609',
#  'cqm_20200610',
#  'cqm_20200611',
#  'cqm_20200612',
#  'cqm_20200615',
#  'cqm_20200616',
#  'cqm_20200617',
#  'cqm_20200618',
#  'cqm_20200619',
#  'cqm_20200622',
#  'cqm_20200623',
#  'cqm_20200624',
#  'cqm_20200625',
#  'cqm_20200626',
#  'cqm_20200629',
#  'cqm_20200630',
#  'cqm_20200701',
#  'cqm_20200702',
#  'cqm_20200706',
#  'cqm_20200707',
#  'cqm_20200708',
#  'cqm_20200709',
#  'cqm_20200710',
#  'cqm_20200713',
#  'cqm_20200714',
#  'cqm_20200715',
#  'cqm_20200716',
#  'cqm_20200717',
#  'cqm_20200720',
#  'cqm_20200721',
#  'cqm_20200722',
#  'cqm_20200723',
#  'cqm_20200724',
#  'cqm_20200727',
#  'cqm_20200728',
#  'cqm_20200729',
#  'cqm_20200730',
#  'cqm_20200731',
#  'cqm_20200803',
#  'cqm_20200804',
#  'cqm_20200805',
#  'cqm_20200806',
#  'cqm_20200807',
#  'cqm_20200810',
#  'cqm_20200811',
#  'cqm_20200812',
#  'cqm_20200813',
#  'cqm_20200814',
#  'cqm_20200817',
#  'cqm_20200818',
#  'cqm_20200819',
#  'cqm_20200820',
#  'cqm_20200821',
#  'cqm_20200824',
#  'cqm_20200825',
#  'cqm_20200826',
#  'cqm_20200827',
#  'cqm_20200828',
#  'cqm_20200831',
#  'cqm_20200901',
#  'cqm_20200902',
#  'cqm_20200903',
#  'cqm_20200904',
#  'cqm_20200908',
#  'cqm_20200909',
#  'cqm_20200910',
#  'cqm_20200911',
#  'cqm_20200914',
#  'cqm_20200915',
#  'cqm_20200916',
#  'cqm_20200917',
#  'cqm_20200918',
#  'cqm_20200921',
#  'cqm_20200922',
#  'cqm_20200923',
#  'cqm_20200924',
#  'cqm_20200925',
#  'cqm_20200928',
#  'cqm_20200929',
#  'cqm_20200930',
#  'cqm_20201001',
#  'cqm_20201002',
#  'cqm_20201005',
#  'cqm_20201006',
#  'cqm_20201007',
#  'cqm_20201008',
#  'cqm_20201009',
#  'cqm_20201012',
#  'cqm_20201013',
#  'cqm_20201014',
#  'cqm_20201015',
#  'cqm_20201016',
#  'cqm_20201019',
#  'cqm_20201020',
#  'cqm_20201021',
#  'cqm_20201022',
#  'cqm_20201023',
#  'cqm_20201026',
#  'cqm_20201027',
#  'cqm_20201028',
#  'cqm_20201029',
#  'cqm_20201030',
#  'cqm_20201102',
#  'cqm_20201103',
#  'cqm_20201104',
#  'cqm_20201105',
#  'cqm_20201106',
#  'cqm_20201109',
#  'cqm_20201110',
#  'cqm_20201111',
#  'cqm_20201112',
#  'cqm_20201113',
#  'cqm_20201116',
#  'cqm_20201117',
#  'cqm_20201118',
#  'cqm_20201119',
#  'cqm_20201120',
#  'cqm_20201123',
#  'cqm_20201124',
#  'cqm_20201125',
#  'cqm_20201127',
#  'cqm_20201130',
#  'cqm_20201201',
#  'cqm_20201202',
#  'cqm_20201203',
#  'cqm_20201204',
#  'cqm_20201207',
#  'cqm_20201208',
#  'cqm_20201209',
#  'cqm_20201210',
#  'cqm_20201211',
#  'cqm_20201214',
#  'cqm_20201215',
#  'cqm_20201216',
#  'cqm_20201217',
#  'cqm_20201218',
#  'cqm_20201221',
#  'cqm_20201222',
#  'cqm_20201223',
#  'cqm_20201224',
#  'cqm_20201228',
#  'cqm_20201229',
#  'cqm_20201230',
#  'cqm_20201231',
#  'ctm_2020',
#  'ctm_20200102',
#  'ctm_20200103',
#  'ctm_20200106',
#  'ctm_20200107',
#  'ctm_20200108',
#  'ctm_20200109',
#  'ctm_20200110',
#  'ctm_20200113',
#  'ctm_20200114',
#  'ctm_20200115',
#  'ctm_20200116',
#  'ctm_20200117',
#  'ctm_20200121',
#  'ctm_20200122',
#  'ctm_20200123',
#  'ctm_20200124',
#  'ctm_20200127',
#  'ctm_20200128',
#  'ctm_20200129',
#  'ctm_20200130',
#  'ctm_20200131',
#  'ctm_20200203',
#  'ctm_20200204',
#  'ctm_20200205',
#  'ctm_20200206',
#  'ctm_20200207',
#  'ctm_20200210',
#  'ctm_20200211',
#  'ctm_20200212',
#  'ctm_20200213',
#  'ctm_20200214',
#  'ctm_20200218',
#  'ctm_20200219',
#  'ctm_20200220',
#  'ctm_20200221',
#  'ctm_20200224',
#  'ctm_20200225',
#  'ctm_20200226',
#  'ctm_20200227',
#  'ctm_20200228',
#  'ctm_20200302',
#  'ctm_20200303',
#  'ctm_20200304',
#  'ctm_20200305',
#  'ctm_20200306',
#  'ctm_20200309',
#  'ctm_20200310',
#  'ctm_20200311',
#  'ctm_20200312',
#  'ctm_20200313',
#  'ctm_20200316',
#  'ctm_20200317',
#  'ctm_20200318',
#  'ctm_20200319',
#  'ctm_20200320',
#  'ctm_20200323',
#  'ctm_20200324',
#  'ctm_20200325',
#  'ctm_20200326',
#  'ctm_20200327',
#  'ctm_20200330',
#  'ctm_20200331',
#  'ctm_20200401',
#  'ctm_20200402',
#  'ctm_20200403',
#  'ctm_20200406',
#  'ctm_20200407',
#  'ctm_20200408',
#  'ctm_20200409',
#  'ctm_20200413',
#  'ctm_20200414',
#  'ctm_20200415',
#  'ctm_20200416',
#  'ctm_20200417',
#  'ctm_20200420',
#  'ctm_20200421',
#  'ctm_20200422',
#  'ctm_20200423',
#  'ctm_20200424',
#  'ctm_20200427',
#  'ctm_20200428',
#  'ctm_20200429',
#  'ctm_20200430',
#  'ctm_20200501',
#  'ctm_20200504',
#  'ctm_20200505',
#  'ctm_20200506',
#  'ctm_20200507',
#  'ctm_20200508',
#  'ctm_20200511',
#  'ctm_20200512',
#  'ctm_20200513',
#  'ctm_20200514',
#  'ctm_20200515',
#  'ctm_20200518',
#  'ctm_20200519',
#  'ctm_20200520',
#  'ctm_20200521',
#  'ctm_20200522',
#  'ctm_20200526',
#  'ctm_20200527',
#  'ctm_20200528',
#  'ctm_20200529',
#  'ctm_20200601',
#  'ctm_20200602',
#  'ctm_20200603',
#  'ctm_20200604',
#  'ctm_20200605',
#  'ctm_20200608',
#  'ctm_20200609',
#  'ctm_20200610',
#  'ctm_20200611',
#  'ctm_20200612',
#  'ctm_20200615',
#  'ctm_20200616',
#  'ctm_20200617',
#  'ctm_20200618',
#  'ctm_20200619',
#  'ctm_20200622',
#  'ctm_20200623',
#  'ctm_20200624',
#  'ctm_20200625',
#  'ctm_20200626',
#  'ctm_20200629',
#  'ctm_20200630',
#  'ctm_20200701',
#  'ctm_20200702',
#  'ctm_20200706',
#  'ctm_20200707',
#  'ctm_20200708',
#  'ctm_20200709',
#  'ctm_20200710',
#  'ctm_20200713',
#  'ctm_20200714',
#  'ctm_20200715',
#  'ctm_20200716',
#  'ctm_20200717',
#  'ctm_20200720',
#  'ctm_20200721',
#  'ctm_20200722',
#  'ctm_20200723',
#  'ctm_20200724',
#  'ctm_20200727',
#  'ctm_20200728',
#  'ctm_20200729',
#  'ctm_20200730',
#  'ctm_20200731',
#  'ctm_20200803',
#  'ctm_20200804',
#  'ctm_20200805',
#  'ctm_20200806',
#  'ctm_20200807',
#  'ctm_20200810',
#  'ctm_20200811',
#  'ctm_20200812',
#  'ctm_20200813',
#  'ctm_20200814',
#  'ctm_20200817',
#  'ctm_20200818',
#  'ctm_20200819',
#  'ctm_20200820',
#  'ctm_20200821',
#  'ctm_20200824',
#  'ctm_20200825',
#  'ctm_20200826',
#  'ctm_20200827',
#  'ctm_20200828',
#  'ctm_20200831',
#  'ctm_20200901',
#  'ctm_20200902',
#  'ctm_20200903',
#  'ctm_20200904',
#  'ctm_20200908',
#  'ctm_20200909',
#  'ctm_20200910',
#  'ctm_20200911',
#  'ctm_20200914',
#  'ctm_20200915',
#  'ctm_20200916',
#  'ctm_20200917',
#  'ctm_20200918',
#  'ctm_20200921',
#  'ctm_20200922',
#  'ctm_20200923',
#  'ctm_20200924',
#  'ctm_20200925',
#  'ctm_20200928',
#  'ctm_20200929',
#  'ctm_20200930',
#  'ctm_20201001',
#  'ctm_20201002',
#  'ctm_20201005',
#  'ctm_20201006',
#  'ctm_20201007',
#  'ctm_20201008',
#  'ctm_20201009',
#  'ctm_20201012',
#  'ctm_20201013',
#  'ctm_20201014',
#  'ctm_20201015',
#  'ctm_20201016',
#  'ctm_20201019',
#  'ctm_20201020',
#  'ctm_20201021',
#  'ctm_20201022',
#  'ctm_20201023',
#  'ctm_20201026',
#  'ctm_20201027',
#  'ctm_20201028',
#  'ctm_20201029',
#  'ctm_20201030',
#  'ctm_20201102',
#  'ctm_20201103',
#  'ctm_20201104',
#  'ctm_20201105',
#  'ctm_20201106',
#  'ctm_20201109',
#  'ctm_20201110',
#  'ctm_20201111',
#  'ctm_20201112',
#  'ctm_20201113',
#  'ctm_20201116',
#  'ctm_20201117',
#  'ctm_20201118',
#  'ctm_20201119',
#  'ctm_20201120',
#  'ctm_20201123',
#  'ctm_20201124',
#  'ctm_20201125',
#  'ctm_20201127',
#  'ctm_20201130',
#  'ctm_20201201',
#  'ctm_20201202',
#  'ctm_20201203',
#  'ctm_20201204',
#  'ctm_20201207',
#  'ctm_20201208',
#  'ctm_20201209',
#  'ctm_20201210',
#  'ctm_20201211',
#  'ctm_20201214',
#  'ctm_20201215',
#  'ctm_20201216',
#  'ctm_20201217',
#  'ctm_20201218',
#  'ctm_20201221',
#  'ctm_20201222',
#  'ctm_20201223',
#  'ctm_20201224',
#  'ctm_20201228',
#  'ctm_20201229',
#  'ctm_20201230',
#  'ctm_20201231',
#  'mastm_2020',
#  'mastm_20200102',
#  'mastm_20200103',
#  'mastm_20200106',
#  'mastm_20200107',
#  'mastm_20200108',
#  'mastm_20200109',
#  'mastm_20200110',
#  'mastm_20200113',
#  'mastm_20200114',
#  'mastm_20200115',
#  'mastm_20200116',
#  'mastm_20200117',
#  'mastm_20200121',
#  'mastm_20200122',
#  'mastm_20200123',
#  'mastm_20200124',
#  'mastm_20200127',
#  'mastm_20200128',
#  'mastm_20200129',
#  'mastm_20200130',
#  'mastm_20200131',
#  'mastm_20200203',
#  'mastm_20200204',
#  'mastm_20200205',
#  'mastm_20200206',
#  'mastm_20200207',
#  'mastm_20200210',
#  'mastm_20200211',
#  'mastm_20200212',
#  'mastm_20200213',
#  'mastm_20200214',
#  'mastm_20200218',
#  'mastm_20200219',
#  'mastm_20200220',
#  'mastm_20200221',
#  'mastm_20200224',
#  'mastm_20200225',
#  'mastm_20200226',
#  'mastm_20200227',
#  'mastm_20200228',
#  'mastm_20200302',
#  'mastm_20200303',
#  'mastm_20200304',
#  'mastm_20200305',
#  'mastm_20200306',
#  'mastm_20200309',
#  'mastm_20200310',
#  'mastm_20200311',
#  'mastm_20200312',
#  'mastm_20200313',
#  'mastm_20200316',
#  'mastm_20200317',
#  'mastm_20200318',
#  'mastm_20200319',
#  'mastm_20200320',
#  'mastm_20200323',
#  'mastm_20200324',
#  'mastm_20200325',
#  'mastm_20200326',
#  'mastm_20200327',
#  'mastm_20200330',
#  'mastm_20200331',
#  'mastm_20200401',
#  'mastm_20200402',
#  'mastm_20200403',
#  'mastm_20200406',
#  'mastm_20200407',
#  'mastm_20200408',
#  'mastm_20200409',
#  'mastm_20200413',
#  'mastm_20200414',
#  'mastm_20200415',
#  'mastm_20200416',
#  'mastm_20200417',
#  'mastm_20200420',
#  'mastm_20200421',
#  'mastm_20200422',
#  'mastm_20200423',
#  'mastm_20200424',
#  'mastm_20200427',
#  'mastm_20200428',
#  'mastm_20200429',
#  'mastm_20200430',
#  'mastm_20200501',
#  'mastm_20200504',
#  'mastm_20200505',
#  'mastm_20200506',
#  'mastm_20200507',
#  'mastm_20200508',
#  'mastm_20200511',
#  'mastm_20200512',
#  'mastm_20200513',
#  'mastm_20200514',
#  'mastm_20200515',
#  'mastm_20200518',
#  'mastm_20200519',
#  'mastm_20200520',
#  'mastm_20200521',
#  'mastm_20200522',
#  'mastm_20200526',
#  'mastm_20200527',
#  'mastm_20200528',
#  'mastm_20200529',
#  'mastm_20200601',
#  'mastm_20200602',
#  'mastm_20200603',
#  'mastm_20200604',
#  'mastm_20200605',
#  'mastm_20200608',
#  'mastm_20200609',
#  'mastm_20200610',
#  'mastm_20200611',
#  'mastm_20200612',
#  'mastm_20200615',
#  'mastm_20200616',
#  'mastm_20200617',
#  'mastm_20200618',
#  'mastm_20200619',
#  'mastm_20200622',
#  'mastm_20200623',
#  'mastm_20200624',
#  'mastm_20200625',
#  'mastm_20200626',
#  'mastm_20200629',
#  'mastm_20200630',
#  'mastm_20200701',
#  'mastm_20200702',
#  'mastm_20200706',
#  'mastm_20200707',
#  'mastm_20200708',
#  'mastm_20200709',
#  'mastm_20200710',
#  'mastm_20200713',
#  'mastm_20200714',
#  'mastm_20200715',
#  'mastm_20200716',
#  'mastm_20200717',
#  'mastm_20200720',
#  'mastm_20200721',
#  'mastm_20200722',
#  'mastm_20200723',
#  'mastm_20200724',
#  'mastm_20200727',
#  'mastm_20200728',
#  'mastm_20200729',
#  'mastm_20200730',
#  'mastm_20200731',
#  'mastm_20200803',
#  'mastm_20200804',
#  'mastm_20200805',
#  'mastm_20200806',
#  'mastm_20200807',
#  'mastm_20200810',
#  'mastm_20200811',
#  'mastm_20200812',
#  'mastm_20200813',
#  'mastm_20200814',
#  'mastm_20200817',
#  'mastm_20200818',
#  'mastm_20200819',
#  'mastm_20200820',
#  'mastm_20200821',
#  'mastm_20200824',
#  'mastm_20200825',
#  'mastm_20200826',
#  'mastm_20200827',
#  'mastm_20200828',
#  'mastm_20200831',
#  'mastm_20200901',
#  'mastm_20200902',
#  'mastm_20200903',
#  'mastm_20200904',
#  'mastm_20200908',
#  'mastm_20200909',
#  'mastm_20200910',
#  'mastm_20200911',
#  'mastm_20200914',
#  'mastm_20200915',
#  'mastm_20200916',
#  'mastm_20200917',
#  'mastm_20200918',
#  'mastm_20200921',
#  'mastm_20200922',
#  'mastm_20200923',
#  'mastm_20200924',
#  'mastm_20200925',
#  'mastm_20200928',
#  'mastm_20200929',
#  'mastm_20200930',
#  'mastm_20201001',
#  'mastm_20201002',
#  'mastm_20201005',
#  'mastm_20201006',
#  'mastm_20201007',
#  'mastm_20201008',
#  'mastm_20201009',
#  'mastm_20201012',
#  'mastm_20201013',
#  'mastm_20201014',
#  'mastm_20201015',
#  'mastm_20201016',
#  'mastm_20201019',
#  'mastm_20201020',
#  'mastm_20201021',
#  'mastm_20201022',
#  'mastm_20201023',
#  'mastm_20201026',
#  'mastm_20201027',
#  'mastm_20201028',
#  'mastm_20201029',
#  'mastm_20201030',
#  'mastm_20201102',
#  'mastm_20201103',
#  'mastm_20201104',
#  'mastm_20201105',
#  'mastm_20201106',
#  'mastm_20201109',
#  'mastm_20201110',
#  'mastm_20201111',
#  'mastm_20201112',
#  'mastm_20201113',
#  'mastm_20201116',
#  'mastm_20201117',
#  'mastm_20201118',
#  'mastm_20201119',
#  'mastm_20201120',
#  'mastm_20201123',
#  'mastm_20201124',
#  'mastm_20201125',
#  'mastm_20201127',
#  'mastm_20201130',
#  'mastm_20201201',
#  'mastm_20201202',
#  'mastm_20201203',
#  'mastm_20201204',
#  'mastm_20201207',
#  'mastm_20201208',
#  ...]

# %%
#'complete_nbbo_2020'
#'cqm_2020'
#'ctm_2020'
#'mastm_2020'

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='taqm_2020', table='cqm_2020')
# Out:
# Approximately 322801791744 rows in taqm_2020.cqm_2020.
#                    name  nullable        type  \
# 0                  date     False        DATE
# 1                time_m     False        TIME
# 2           time_m_nano      True    SMALLINT
# 3                    ex      True  VARCHAR(1)
# 4              sym_root     False        TEXT
# 5            sym_suffix      True        TEXT
# 6                   bid      True     NUMERIC
# 7                bidsiz      True     INTEGER
# 8                   ask      True     NUMERIC
# 9                asksiz      True     INTEGER
# 10              qu_cond      True  VARCHAR(1)
# 11            qu_seqnum      True      BIGINT
# 12           natbbo_ind      True  VARCHAR(1)
# 13            qu_cancel      True  VARCHAR(1)
# 14            qu_source      True  VARCHAR(1)
# 15                  rpi      True  VARCHAR(1)
# 16                  ssr      True  VARCHAR(1)
# 17   luld_bbo_indicator      True  VARCHAR(1)
# 18        finra_bbo_ind      True  VARCHAR(1)
# 19       finra_adf_mpid      True  VARCHAR(1)
# 20       finra_adf_time      True        TIME
# 21  finra_adf_time_nano      True    SMALLINT
# 22    finra_adf_mpq_ind      True  VARCHAR(1)
# 23   finra_adf_mquo_ind      True  VARCHAR(1)
# 24       sip_message_id      True  VARCHAR(1)
# 25        natl_bbo_luld      True  VARCHAR(1)
# 26            part_time      True        TIME
# 27       part_time_nano      True    SMALLINT
# 28          secstat_ind      True  VARCHAR(1)
#
#                                          comment
# 0                                  Date of quote
# 1                        Time to the microsecond
# 2                              Nanosecond offset
# 3                 Exchange that issued the quote
# 4                           Security symbol root
# 5                         Security symbol suffix
# 6                                      Bid price
# 7                     Bid size in units of trade
# 8                                      Ask price
# 9                     Ask size in units of trade
# 10                     Condition of quote issued
# 11                         Quote Sequence Number
# 12                        National BBO Indicator
# 13                       Quote Cancel/Correction
# 14                               Source of Quote
# 15                     Retail Interest Indicator
# 16                        Short Sale Restriction
# 17                                          None
# 18                    FINRA BBO (FBBO) Indicator
# 19                      FINRA ADF MPID Indicator
# 20                           FINRA ADF Timestamp
# 21                             Nanosecond offset
# 22                                          None
# 23  FINRA ADF Market Participant Quote Indicator
# 24               SIP-generated Message Indicator
# 25                   National BBO LULD Indicator
# 26                         Participant Timestamp
# 27                             Nanosecond offset
# 28                     Security Status Indicator

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='taqm_2020', table='ctm_2020')
# Out:
# Approximately 14862857505 rows in taqm_2020.ctm_2020.
#               name  nullable        type  \
# 0             date     False        DATE
# 1           time_m     False        TIME
# 2      time_m_nano      True    SMALLINT
# 3               ex      True  VARCHAR(1)
# 4         sym_root     False        TEXT
# 5       sym_suffix      True        TEXT
# 6         tr_scond      True  VARCHAR(4)
# 7             size      True     INTEGER
# 8            price      True     NUMERIC
# 9      tr_stop_ind      True  VARCHAR(1)
# 10         tr_corr      True  VARCHAR(2)
# 11       tr_seqnum      True      BIGINT
# 12           tr_id      True        TEXT
# 13       tr_source      True  VARCHAR(1)
# 14           tr_rf      True  VARCHAR(1)
# 15       part_time      True        TIME
# 16  part_time_nano      True    SMALLINT
# 17        trf_time      True        TIME
# 18   trf_time_nano      True    SMALLINT
# 19         tte_ind      True  VARCHAR(1)
#
#                                    comment
# 0                            Date of trade
# 1                  Time to the microsecond
# 2                        Nanosecond offset
# 3           Exchange that issued the trade
# 4                     Security symbol root
# 5                   Security symbol suffix
# 6     Trade Sale Condition (up to 4 codes)
# 7                          Volume of trade
# 8                           Price of trade
# 9   Trade Stop Stock Indicator (NYSE Only)
# 10              Trade Correction Indicator
# 11                   Trade Sequence Number
# 12                                Trade ID
# 13                         Source of Trade
# 14                Trade Reporting Facility
# 15                   Participant Timestamp
# 16                       Nanosecond offset
# 17      Trade Reporting Facility Timestamp
# 18                       Nanosecond offset
# 19                                    None

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='taqm_2020', table='complete_nbbo_2020')
# Out:
# Approximately 64665607454 rows in taqm_2020.complete_nbbo_2020.
#                   name  nullable        type  \
# 0                 date     False        DATE
# 1               time_m     False        TIME
# 2          time_m_nano      True    SMALLINT
# 3             sym_root     False        TEXT
# 4           sym_suffix      True        TEXT
# 5              qu_cond      True  VARCHAR(1)
# 6           natbbo_ind      True  VARCHAR(1)
# 7            qu_source      True  VARCHAR(1)
# 8         nbbo_qu_cond      True  VARCHAR(1)
# 9             best_bid      True     NUMERIC
# 10  best_bidsizeshares      True     INTEGER
# 11            best_ask      True     NUMERIC
# 12  best_asksizeshares      True     INTEGER
#
#                                               comment
# 0                                       Date of quote
# 1                                          Trade Time
# 2                         Nanosecond offset of time_m
# 3                                Security symbol root
# 4                              Security symbol suffix
# 5                           Condition of quote issued
# 6                         Effect of new quote on NBBO
# 7                                                None
# 8                                                None
# 9                                   National Best Bid
# 10  Maximum Bid Size of all exchanges at National ...
# 11                                National Best Offer
# 12  Maximum Offer Size of all exchanges at Nationa...

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='taqm_2020', table='mastm_2020')
# Out:
# Approximately 2288158 rows in taqm_2020.mastm_2020.
#                          name  nullable        type  \
# 0                        date     False        DATE
# 1                   symbol_15      True        TEXT
# 2                    sec_desc      True        TEXT
# 3                       cusip      True        TEXT
# 4                    sec_type      True        TEXT
# 5                  cta_symbol      True        TEXT
# 6                  old_symbol      True        TEXT
# 7            test_symbol_flag      True        TEXT
# 8             listed_exchange      True        TEXT
# 9                        tape      True  VARCHAR(1)
# 10                        uot      True     INTEGER
# 11                  round_lot      True     INTEGER
# 12         nyse_industry_code      True        TEXT
# 13         shares_outstanding      True     NUMERIC
# 14          halt_delay_reason      True        TEXT
# 15  specialist_clearing_agent      True        TEXT
# 16    specialist_clearing_num      True     INTEGER
# 17        specialist_post_num      True     INTEGER
# 18           specialist_panel      True        TEXT
# 19               tron_nysemkt      True        TEXT
# 20              tron_nasdaqbx      True        TEXT
# 21                   tron_nsx      True  VARCHAR(1)
# 22                 tron_finra      True  VARCHAR(1)
# 23                   tron_ise      True  VARCHAR(1)
# 24                tron_edge_a      True  VARCHAR(1)
# 25                tron_edge_x      True  VARCHAR(1)
# 26                   tron_chx      True  VARCHAR(1)
# 27                  tron_nyse      True  VARCHAR(1)
# 28                  tron_arca      True  VARCHAR(1)
# 29                tron_nasdaq      True  VARCHAR(1)
# 30                  tron_cboe      True  VARCHAR(1)
# 31                   tron_psx      True  VARCHAR(1)
# 32                 tron_batsy      True  VARCHAR(1)
# 33                  tron_bats      True  VARCHAR(1)
# 34                   tron_iex      True        TEXT
# 35       tick_pilot_indicator      True        TEXT
# 36             effective_date      True        DATE
# 37                  tron_ltse      True        TEXT
# 38                  tron_memx      True        TEXT
# 39                  tron_miax      True        TEXT
#
#                                               comment
# 0                                                None
# 1                 Trading SYMBOL (from MASTM dataset)
# 2                                Security Description
# 3                                    CUSIP (9 digits)
# 4                                       Security Type
# 5                                          CTA Symbol
# 6                                          Old Symbol
# 7        Test Symbol Flag ("Y"=this is a test symbol)
# 8                    Listing Exchange of the Security
# 9                                     Tape A, B, or C
# 10              Minimum size that a trade is executed
# 11        The number of shares the security quotes at
# 12                                               None
# 13       Shares outstanding on this date, in millions
# 14  Denotes the reason for the Opening Delay or Tr...
# 15         Specialist Clear Firm (for NYSE, NYSE MKT)
# 16   Specialist Clearing Number for NYSE and NYSE MKT
# 17             Specialist Identifier (NYSE, NYSE MKT)
# 18                                   Specialist Panel
# 19                 Traded on NYSE MKT Today ("1"=yes)
# 20                Traded on NABDAQ BX Today ("1"=yes)
# 21                      Traded on NSX today ("1"=yes)
# 22                    Traded on FINRA today ("1"=yes)
# 23                      Traded on ISE today ("1"=yes)
# 24                   Traded on EDGE A today ("1"=yes)
# 25                   Traded on EDGE X today ("1"=yes)
# 26                      Traded on CHX today ("1"=yes)
# 27                     Traded on NYSE today ("1"=yes)
# 28                     Traded on ARCA today ("1"=yes)
# 29                   Traded on NASDAQ today ("1"=yes)
# 30                     Traded on CBOE today ("1"=yes)
# 31                      Traded on PSX today ("1"=yes)
# 32                 Traded on BATS BYX today ("1"=yes)
# 33                 Traded on BATS BZX today ("1"=yes)
# 34                      Traded on IEX today ("1"=yes)
# 35                        Tick Pilot Securities Group
# 36                                     Effective Date
# 37                     Traded on LTSE today ("1"=yes)
# 38                     Traded on MEMX today ("1"=yes)
# 39                     Traded on MIAX today ("1"=yes)

# %%
#import wrds
#db = wrds.Connection()
taq = db.raw_sql("""
                    select *
                      from taqm_2020.cqm_20200102
                     where sym_root = 'AAPL'
                     --and date = '01/02/2020'
                --order by time_m
                """)
taq
# Out:
#               date           time_m  time_m_nano ex sym_root sym_suffix  \
# 0       2020-01-02  04:00:00.065166          598  P     AAPL       None
# 1       2020-01-02  04:00:00.065167          494  P     AAPL       None
# 2       2020-01-02  04:00:00.065170           70  P     AAPL       None
# 3       2020-01-02  04:00:00.065682          670  P     AAPL       None
# 4       2020-01-02  04:00:00.065739          537  P     AAPL       None
# ...            ...              ...          ... ..      ...        ...
# 425182  2020-01-02  19:59:52.611834          975  Q     AAPL       None
# 425183  2020-01-02  19:59:53.854853          307  K     AAPL       None
# 425184  2020-01-02  19:59:53.856007          297  K     AAPL       None
# 425185  2020-01-02  19:59:57.964151          994  K     AAPL       None
# 425186  2020-01-02  19:59:57.964164          722  K     AAPL       None
#
#            bid  bidsiz     ask  asksiz  ... finra_adf_mpid  finra_adf_time  \
# 0       278.00       7    0.00       0  ...           None            None
# 1       278.00      14    0.00       0  ...           None            None
# 2       293.72       9    0.00       0  ...           None            None
# 3       293.72       9  327.56       1  ...           None            None
# 4       293.72       9  320.00       1  ...           None            None
# ...        ...     ...     ...     ...  ...            ...             ...
# 425182  301.19       1  302.00       6  ...           None            None
# 425183  301.10      46  301.25       2  ...           None            None
# 425184  301.10      46  301.25       2  ...           None            None
# 425185  301.10      46  301.25       2  ...           None            None
# 425186  301.10      46  301.25       1  ...           None            None
#
#        finra_adf_time_nano finra_adf_mpq_ind finra_adf_mquo_ind  \
# 0                        0              None               None
# 1                        0              None               None
# 2                        0              None               None
# 3                        0              None               None
# 4                        0              None               None
# ...                    ...               ...                ...
# 425182                   0              None               None
# 425183                   0              None               None
# 425184                   0              None               None
# 425185                   0              None               None
# 425186                   0              None               None
#
#        sip_message_id natl_bbo_luld        part_time part_time_nano  \
# 0                None          None  04:00:00.064786            664
# 1                None          None  04:00:00.064787            456
# 2                None          None  04:00:00.064791            784
# 3                None          None  04:00:00.065302            272
# 4                None          None  04:00:00.065359            592
# ...               ...           ...              ...            ...
# 425182           None          None  19:59:52.611817              2
# 425183           None          None  19:59:53.854647              0
# 425184           None          None  19:59:53.855780              0
# 425185           None          None  19:59:57.963903              0
# 425186           None          None  19:59:57.963903              0
#
#        secstat_ind
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 425182        None
# 425183        None
# 425184        None
# 425185        None
# 425186        None
#
# [1925187 rows x 29 columns]

# %%
#import wrds
#db = wrds.Connection()
taq = db.raw_sql("""
                    select count (*)
                     from taqm_2020.cqm_20200102
                    where sym_root = 'AAPL'
                    --and date ='01/02/2020'
               --order by time_m
                """)
taq
# Out:
#      count
# 0  1925187

# %%
#import wrds
#db = wrds.Connection()
taq = db.raw_sql("""
                    select count (*)
                      from taqm_2020.cqm_20200102
                     where sym_root = 'AAPL'
                     --and date ='01/02/2020'
                       and sym_suffix is not null
                --order by time_m
                """)
taq
# Out:
#    count
# 0      0

# %%
#import wrds
#db = wrds.Connection()
taq = db.raw_sql("""
                    select
                    case when sym_suffix is not null then 'CHK' end as "CHK", a.*
                      from taqm_2020.cqm_20200102 a
                     where sym_root = 'AAPL'
                     --and date ='01/02/2020'
                  order by 1 --time_m
                --order by 1 desc
                """)
taq
# Out:
#          CHK        date           time_m  time_m_nano ex sym_root sym_suffix  \
# 0       None  2020-01-02  04:00:00.065166          598  P     AAPL       None
# 1       None  2020-01-02  04:00:00.065167          494  P     AAPL       None
# 2       None  2020-01-02  04:00:00.065170           70  P     AAPL       None
# 3       None  2020-01-02  04:00:00.065682          670  P     AAPL       None
# 4       None  2020-01-02  04:00:00.065739          537  P     AAPL       None
# ...      ...         ...              ...          ... ..      ...        ...
# 425182  None  2020-01-02  15:01:36.582840          485  Q     AAPL       None
# 425183  None  2020-01-02  15:01:36.582884          391  Q     AAPL       None
# 425184  None  2020-01-02  15:01:36.583587          702  P     AAPL       None
# 425185  None  2020-01-02  15:01:36.583596          100  X     AAPL       None
# 425186  None  2020-01-02  15:01:36.583626          622  Z     AAPL       None
#
#            bid  bidsiz     ask  ...  finra_adf_mpid finra_adf_time  \
# 0       278.00       7    0.00  ...            None           None
# 1       278.00      14    0.00  ...            None           None
# 2       293.72       9    0.00  ...            None           None
# 3       293.72       9  327.56  ...            None           None
# 4       293.72       9  320.00  ...            None           None
# ...        ...     ...     ...  ...             ...            ...
# 425182  299.15       2  299.18  ...            None           None
# 425183  299.15       2  299.18  ...            None           None
# 425184  299.15       1  299.17  ...            None           None
# 425185  299.14       1  299.18  ...            None           None
# 425186  299.15       2  299.17  ...            None           None
#
#         finra_adf_time_nano finra_adf_mpq_ind finra_adf_mquo_ind  \
# 0                         0              None               None
# 1                         0              None               None
# 2                         0              None               None
# 3                         0              None               None
# 4                         0              None               None
# ...                     ...               ...                ...
# 425182                    0              None               None
# 425183                    0              None               None
# 425184                    0              None               None
# 425185                    0              None               None
# 425186                    0              None               None
#
#        sip_message_id natl_bbo_luld        part_time part_time_nano  \
# 0                None          None  04:00:00.064786            664
# 1                None          None  04:00:00.064787            456
# 2                None          None  04:00:00.064791            784
# 3                None          None  04:00:00.065302            272
# 4                None          None  04:00:00.065359            592
# ...               ...           ...              ...            ...
# 425182           None             A  15:01:36.582824            349
# 425183           None             A  15:01:36.582868            433
# 425184           None             A  15:01:36.583210            728
# 425185           None             A  15:01:36.583578            944
# 425186           None             A  15:01:36.583439              0
#
#        secstat_ind
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 425182        None
# 425183        None
# 425184        None
# 425185        None
# 425186        None
#
# [1925187 rows x 30 columns]

# %%
#import wrds
#db = wrds.Connection()
taq = db.raw_sql("""select count(*)
                      from taqm_2020.cqm_20200102
                     where sym_root = 'AAPL'
                     --and date ='01/02/2020'

                     --and time_m >= '04:00:00.065166'
                       and time_m >= '04:00:00'

                --order by time_m
                 """)
taq
# Out:
#      count
# 0  1925187

# %%
###

# %%
#import wrds
#db = wrds.Connection()

#db.describe_table(library='taqm_2020', table='cqm_2020')
db.describe_table(library='taqmsec', table='cqm_2020')
# Out:
# Approximately 322801791744 rows in taqmsec.cqm_2020.
#                    name  nullable        type comment
# 0                  date      True        DATE    None
# 1                time_m      True        TIME    None
# 2           time_m_nano      True    SMALLINT    None
# 3                    ex      True  VARCHAR(1)    None
# 4              sym_root      True        TEXT    None
# 5            sym_suffix      True        TEXT    None
# 6                   bid      True     NUMERIC    None
# 7                bidsiz      True     INTEGER    None
# 8                   ask      True     NUMERIC    None
# 9                asksiz      True     INTEGER    None
# 10              qu_cond      True  VARCHAR(1)    None
# 11            qu_seqnum      True      BIGINT    None
# 12           natbbo_ind      True  VARCHAR(1)    None
# 13            qu_cancel      True  VARCHAR(1)    None
# 14            qu_source      True  VARCHAR(1)    None
# 15                  rpi      True  VARCHAR(1)    None
# 16                  ssr      True  VARCHAR(1)    None
# 17   luld_bbo_indicator      True  VARCHAR(1)    None
# 18        finra_bbo_ind      True  VARCHAR(1)    None
# 19       finra_adf_mpid      True  VARCHAR(1)    None
# 20       finra_adf_time      True        TIME    None
# 21  finra_adf_time_nano      True    SMALLINT    None
# 22    finra_adf_mpq_ind      True  VARCHAR(1)    None
# 23   finra_adf_mquo_ind      True  VARCHAR(1)    None
# 24       sip_message_id      True  VARCHAR(1)    None
# 25        natl_bbo_luld      True  VARCHAR(1)    None
# 26            part_time      True        TIME    None
# 27       part_time_nano      True    SMALLINT    None
# 28          secstat_ind      True  VARCHAR(1)    None

# %% [markdown]
# ### OPTIONMETRICS

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
om = [x for x in lib if 'option' in x]
om
# Out:
# ['optionm',
#  'optionm_all',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'wrdsapps_link_crsp_optionm']

# %%
tables = db.list_tables(library='optionm')
len(tables)
#tables
# Out:
# 356

# %%
tables = db.list_tables(library='optionm_all')
len(tables)
#tables
# Out:
# 208

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm_all', table='idxdvd').shape
# Out:
# Approximately 359324 rows in optionm_all.idxdvd.
# (3, 4)

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm', table='idxdvd').shape
# Out:
# Approximately 359324 rows in optionm.idxdvd.
# (3, 4)

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm_all', table='idxdvd')
# Out:
# Approximately 359324 rows in optionm_all.idxdvd.
#     name  nullable              type comment
# 0  secid      True  DOUBLE_PRECISION    None
# 1   date      True              DATE    None
# 2   rate      True  DOUBLE_PRECISION    None

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm', table='idxdvd')
# Out:
# Approximately 359324 rows in optionm.idxdvd.
#     name  nullable              type comment
# 0  secid      True  DOUBLE_PRECISION    None
# 1   date      True              DATE    None
# 2   rate      True  DOUBLE_PRECISION    None

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm_all', table='securd1')
# Out:
# Approximately 117082 rows in optionm_all.securd1.
#              name  nullable              type comment
# 0           secid      True  DOUBLE_PRECISION    None
# 1           cusip      True        VARCHAR(8)    None
# 2          ticker      True        VARCHAR(6)    None
# 3             sic      True        VARCHAR(4)    None
# 4      index_flag      True        VARCHAR(1)    None
# 5      exchange_d      True  DOUBLE_PRECISION    None
# 6           class      True        VARCHAR(1)    None
# 7      issue_type      True        VARCHAR(1)    None
# 8  industry_group      True  DOUBLE_PRECISION    None
# 9          issuer      True       VARCHAR(28)    None

# %%
#import wrds
#db = wrds.Connection()
index_div_yield = db.raw_sql("""
                                select *
                                  from optionm_all.idxdvd a, optionm_all.securd1 b
                                 where a.secid = b.secid
                                   and b.ticker = 'SPX'
                                   and a.date >= '01/01/2020'
                                   and a.date <= '12/31/2021'
                              order by a.date
                             """,
                             date_cols=['a.date'])
index_div_yield.shape
# Out:
# (505, 13)

# %%
index_div_yield
# Out:
#         secid        date      rate     secid     cusip ticker   sic  \
# 0    108105.0  2020-01-02  1.777138  108105.0  64881510    SPX  9999
# 1    108105.0  2020-01-03  1.783770  108105.0  64881510    SPX  9999
# 2    108105.0  2020-01-06  1.804811  108105.0  64881510    SPX  9999
# 3    108105.0  2020-01-07  1.809661  108105.0  64881510    SPX  9999
# 4    108105.0  2020-01-08  1.797900  108105.0  64881510    SPX  9999
# ..        ...         ...       ...       ...       ...    ...   ...
# 500  108105.0  2021-12-27  1.245086  108105.0  64881510    SPX  9999
# 501  108105.0  2021-12-28  1.248356  108105.0  64881510    SPX  9999
# 502  108105.0  2021-12-29  1.252619  108105.0  64881510    SPX  9999
# 503  108105.0  2021-12-30  1.246516  108105.0  64881510    SPX  9999
# 504  108105.0  2021-12-31  1.243227  108105.0  64881510    SPX  9999
#
#     index_flag  exchange_d class issue_type industry_group              issuer
# 0            1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 1            1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 2            1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 3            1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 4            1     32768.0  None          A           None  CBOE S&P 500 INDEX
# ..         ...         ...   ...        ...            ...                 ...
# 500          1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 501          1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 502          1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 503          1     32768.0  None          A           None  CBOE S&P 500 INDEX
# 504          1     32768.0  None          A           None  CBOE S&P 500 INDEX
#
# [505 rows x 13 columns]

# %%
#import wrds
#db = wrds.Connection()
index_div_yield = db.raw_sql("""
                                select *
                                  from optionm_all.idxdvd a, optionm_all.securd1 b
                                 where a.secid = b.secid
                                   and b.ticker = 'SPX'
                                   and a.date >= '01/01/2020'
                                   and a.date <= '12/31/2021'
                                   and b.class is not null
                              order by a.date
                             """,
                             date_cols=['a.date'])
index_div_yield.shape
# Out:
# (0, 13)

# %%
#import wrds
#db = wrds.Connection()
index_div_yield = db.raw_sql("""
                                select *
                                  from optionm_all.idxdvd a, optionm_all.securd1 b
                                 where a.secid = b.secid
                                   and b.ticker = 'SPX'
                                   and a.date >= '01/01/2020'
                                   and a.date <= '12/31/2021'
                                   and b.industry_group is not null
                              order by a.date
                             """,
                             date_cols=['a.date'])
index_div_yield.shape

# "and b.class is not null" checks if b.class has a value. Output is null.
# Out:
# (0, 13)

# %%
#import wrds
#db = wrds.Connection()
index_div_yield = db.raw_sql("""
                                select *
                                  from optionm_all.idxdvd a, optionm_all.securd1 b
                                 where a.secid = b.secid
                                   and b.ticker = 'SPX'
                                   and a.date >= '01/01/2020'
                                   and a.date <= '12/31/2021'
                                   and (b.class is not null or industry_group is not null)
                              order by a.date
                             """,
                             date_cols=['a.date'])
index_div_yield.shape

# "and b.industry_group is not null" checks if b.industry_group has a value. Output is null.
# Out:
# (0, 13)

# %%
index_div_yield = db.raw_sql("""
                                select
                                        b.issuer,
                                        b.issue_type,
                                        b.index_flag,
                                        b.exchange_d,
                                        b.sic,
                                        b.secid,
                                        b.ticker,
                                        b.cusip,
                                        a.date,
                                        a.rate
                                 from optionm_all.idxdvd a, optionm_all.securd1 b
                                where a.secid = b.secid
                                  and b.ticker = 'SPX'
                                  and a.date >= '01/01/2020'
                                  and a.date <= '12/31/2021'
                             order by a.date
                             """,
                             date_cols=['a.date'])
index_div_yield.shape
# Out:
# (505, 10)

# %%
index_div_yield
# Out:
#                  issuer issue_type index_flag  exchange_d   sic     secid  \
# 0    CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 1    CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 2    CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 3    CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 4    CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# ..                  ...        ...        ...         ...   ...       ...
# 500  CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 501  CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 502  CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 503  CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
# 504  CBOE S&P 500 INDEX          A          1     32768.0  9999  108105.0
#
#     ticker     cusip        date      rate
# 0      SPX  64881510  2020-01-02  1.777138
# 1      SPX  64881510  2020-01-03  1.783770
# 2      SPX  64881510  2020-01-06  1.804811
# 3      SPX  64881510  2020-01-07  1.809661
# 4      SPX  64881510  2020-01-08  1.797900
# ..     ...       ...         ...       ...
# 500    SPX  64881510  2021-12-27  1.245086
# 501    SPX  64881510  2021-12-28  1.248356
# 502    SPX  64881510  2021-12-29  1.252619
# 503    SPX  64881510  2021-12-30  1.246516
# 504    SPX  64881510  2021-12-31  1.243227
#
# [505 rows x 10 columns]

# %%
###

# %%
#import wrds
#db = wrds.Connection()
db.describe_table(library='optionm_all', table='hvold2006')
# Out:
# Approximately 9267191 rows in optionm_all.hvold2006.
#          name  nullable              type comment
# 0       secid      True  DOUBLE_PRECISION    None
# 1        date      True              DATE    None
# 2        days      True  DOUBLE_PRECISION    None
# 3  volatility      True  DOUBLE_PRECISION    None

# %%
db.describe_table(library='optionm_all', table='hvold2007')
# Out:
# Approximately 10207350 rows in optionm_all.hvold2007.
#          name  nullable              type comment
# 0       secid      True  DOUBLE_PRECISION    None
# 1        date      True              DATE    None
# 2        days      True  DOUBLE_PRECISION    None
# 3  volatility      True  DOUBLE_PRECISION    None

# %%
apple_2007_0109 = db.raw_sql("""
                                select  b.secid,
                                        a.date,
                                        a.volatility,
                                        b.cusip,
                                        b.ticker
                                 from optionm_all.hvold2007 a, optionm_all.securd1 b
                                where a.secid = b.secid
                                  and b.ticker = 'AAPL'
                                  and a.date >= '01/01/2007'
                                  and a.date <= '01/23/2007'
                                  and a.days = '10'
                           --order by a.date
                                UNION
                                select  d.secid,
                                        c.date,
                                        c.volatility,
                                        d.cusip,
                                        d.ticker
                                 from optionm_all.hvold2006 c, optionm_all.securd1 d
                                where c.secid = d.secid
                                  and d.ticker = 'AAPL'
                                  and c.date >= '12/26/2006'
                                  and c.date <= '12/31/2006'
                                  and c.days = '10'
                           --order by b.date
                             order by 1
                             """,
                             date_cols=['a.date', 'c.date'])
apple_2007_0109
# Out:
#        secid        date  volatility     cusip ticker
# 0   101594.0  2006-12-26    0.205269  03783310   AAPL
# 1   101594.0  2006-12-27    0.201526  03783310   AAPL
# 2   101594.0  2006-12-28    0.169768  03783310   AAPL
# 3   101594.0  2006-12-29    0.371294  03783310   AAPL
# 4   101594.0  2007-01-03    0.397631  03783310   AAPL
# 5   101594.0  2007-01-04    0.374491  03783310   AAPL
# 6   101594.0  2007-01-05    0.371933  03783310   AAPL
# 7   101594.0  2007-01-08    0.241744  03783310   AAPL
# 8   101594.0  2007-01-09    0.591668  03783310   AAPL
# 9   101594.0  2007-01-10    0.562254  03783310   AAPL
# 10  101594.0  2007-01-11    0.554048  03783310   AAPL
# 11  101594.0  2007-01-12    0.539441  03783310   AAPL
# 12  101594.0  2007-01-16    0.578026  03783310   AAPL
# 13  101594.0  2007-01-17    0.591300  03783310   AAPL
# 14  101594.0  2007-01-18    0.763410  03783310   AAPL
# 15  101594.0  2007-01-19    0.561386  03783310   AAPL
# 16  101594.0  2007-01-22    0.513608  03783310   AAPL
# 17  101594.0  2007-01-23    0.460367  03783310   AAPL

# %%
#https://www.history.com/this-day-in-history/steve-jobs-debuts-the-iphone

# %% [markdown]
# ### EXTRA: CRSP's S&P 500 Historical Constituents

# %%
#All 559 constituents of S&P 500 that were members at any time during the 3-year period between 2021 and 2023
spx_2023_to_2021 = db.raw_sql("""
                              select permno, mbrstartdt, mbrenddt
                                from crsp_a_indexes.dsp500list_v2
                               where not (mbrenddt < '01/01/2021')
                            order by 3, 2
                      """)
spx_2023_to_2021
# Out:
#      permno  mbrstartdt    mbrenddt
# 0     75100  2000-06-21  2021-01-06
# 1     92239  2016-02-22  2021-01-20
# 2     16538  2017-01-17  2021-02-11
# 3     27983  1963-09-05  2021-03-19
# 4     30940  2008-10-02  2021-03-19
# ..      ...         ...         ...
# 554   92203  2023-10-18  2023-12-29
# 555   32942  2023-10-18  2023-12-29
# 556   79094  2023-12-18  2023-12-29
# 557   18576  2023-12-18  2023-12-29
# 558   90720  2023-12-18  2023-12-29
#
# [559 rows x 3 columns]

# %%
#All 521 constituents of S&P 500 that were members at any time in 2023 (grouped by ‘member end date’)
spx_2023 = db.raw_sql("""
                      select mbrenddt, count (*)
                        from crsp_a_indexes.dsp500list_v2
                       where not (mbrenddt < '01/01/2023')
                    group by mbrenddt
                    order by 1
                      """)
spx_2023
# Out:
#       mbrenddt  count
# 0   2023-01-04      1
# 1   2023-03-14      2
# 2   2023-03-17      1
# 3   2023-05-03      1
# 4   2023-06-16      1
# 5   2023-07-05      2
# 6   2023-08-24      1
# 7   2023-09-15      2
# 8   2023-10-02      2
# 9   2023-10-17      2
# 10  2023-12-15      3
# 11  2023-12-29    503

# %%
#All 521 constituents of S&P 500 that were members at any time in 2023 (grouped by ‘member start date’)
spx_2023 = db.raw_sql("""
                      select mbrstartdt, count (*)
                        from crsp_a_indexes.dsp500list_v2
                       where not (mbrenddt < '01/01/2023')
                    group by mbrstartdt
                    order by 1
                      """)
spx_2023
# Out:
#      mbrstartdt  count
# 0    1925-12-31      8
# 1    1944-06-07      2
# 2    1948-07-07      1
# 3    1949-07-06      1
# 4    1951-09-06      1
# ..          ...    ...
# 396  2023-08-25      1
# 397  2023-09-18      2
# 398  2023-10-02      2
# 399  2023-10-18      2
# 400  2023-12-18      3
#
# [401 rows x 2 columns]

# %% [markdown]
# Note 1: Given that the earliest data available date for CRSP is 31 December 1925, it is important to recognise that a stock entity with a 'member start date' of 31 December 1925 would be either: (i) a member of the SPX (or its predecessors) beginning 31 December 1925, or (ii) potentially a member the SPX (or its predecessors) before 31 December 1925 but the date was defaulted to 31 December 1925, or (iii) possibly having no recognisable 'member start date' and hence the date was defaulted to 31 December 1925.
#
# Note 2: From Britannica Money, the S&P 500 Index (SPX), was formerly called the Composite Index and later Standard & Poor’s Composite Index. It was launched on a small scale in 1923, began tracking 90 stocks in 1926, and expanded to 500 in 1957. https://www.britannica.com/money/SandP-500

# %% [markdown]
# Article: Notes and Thoughts on Retrieving Historical Members of S&P 500 from WRDS
#
# https://library.smu.edu.sg/topics-insights/notes-and-thoughts-retrieving-historical-members-sp-500-wrds
